# %% [markdown]
# # Model fitting and understanding .
# * V2: The operation process is simplified.

# %% [markdown]
# * Turn the warning off:
# ~~~~
# options(warn=-1)
# ~~~~
# * Turn the warning back on:
# ~~~~
# options(warn=0)
# ~~~~
# * reference: https://stackoverflow.com/questions/16194212/how-to-suppress-warnings-globally-in-an-r-script

# %%
options(warn=-1)

# %% [markdown]
# ## First step is getting the correlationship between those variables.

# %%
library(rms)
data <- read.csv('J:/EECS6414/process/Pipeline/Data_cleaning/kernel_datssource_code_3.csv')# , stringsAsFactors=FALSE

col_name <- names(data)
env_vars <- col_name
vote_num <- data[c("km_votes")]
high_voted <- data[c("high_voted")]
reject_vars <- c(#"kernel_datasets", # because they are all 1, so we can only get NaN. 
                 "kernel", "author", "id", "km_language", "km_tags", "cvp_import", "cvp_import_from", 
                "km_votes", "high_voted",  
                "km_forks", "km_comments", "km_views"
                 #"competition", "organization" # unnecessary variables. 
                 )
env_vars <- env_vars[!(env_vars %in% reject_vars)]
# for (env in env_vars){
#    print(paste(env, "+"))
# }
data <- data[env_vars]
# Out:
# Loading required package: Hmisc
# Loading required package: lattice
# Loading required package: survival
# Loading required package: Formula
# Loading required package: ggplot2
#
# Attaching package: 'Hmisc'
#
# The following objects are masked from 'package:base':
#
#     format.pval, units
#
# Loading required package: SparseM
#
# Attaching package: 'SparseM'
#
# The following object is masked from 'package:base':
#
#     backsolve

# %%
vcobj = varclus(~ ., 
                
                data = data, 
                
                similarity = "spearman",
                
                trans = "abs"
)

pdf(file="correlation.pdf", width = 15, height = 15)
plot(vcobj)
thresh = 0.7
abline (h = 1 - thresh, col = "red", lty = 2)
dev.off()

plot(vcobj)
thresh = 0.7
abline (h = 1 - thresh, col = "red", lty = 2)

# reject variables that closely related to each other. For now, we don't do this thing. 
# reject_vars <- c()
# env_vars <- env_vars[!(env_vars %in% reject_vars)]
# Out:
# png
#   2
# plot without title

# %%
env_vars <- c(
    "km_tags_te_avg", 
    "cvp_comments", 
    "cvp_iptfrm_te_avg", 
    "cvp_ipt_te_avg", 
    "cvp_sloc", 
    "km_dataset_discussion_avg", 
    "km_competition_size_avg", 
    "km_dataset_vote_avg",
    "km_isNotebook",
    "cvo_num_of_output", 
    "cvo_display_data", 
    "km_null",
    "km_Other", 
    "km_versions", 
    "cvp_iptfrm_te_min", 
    "km_Visualization", 
    "cvp_ipt_te_min", 
    "cvp_num_of_iptfrm", 
    "km_Data", 
    "cvo_error", 
    "km_dataSources"
             )
data <- data[env_vars]

# %%
vcobj = varclus(~ .,
                
                data = data, 
                
                similarity = "spearman",
                
                trans = "abs"
)

pdf(file="correlation1.pdf", width = 11, height = 8.5)
plot(vcobj)
thresh = 0.7
abline (h = 1 - thresh, col = "red", lty = 2)
dev.off()

plot(vcobj)
thresh = 0.7
abline (h = 1 - thresh, col = "red", lty = 2)

# reject variables that closely related to each other. For now, we don't do this thing. 
reject_vars <- c()
env_vars <- env_vars[!(env_vars %in% reject_vars)]
# Out:
# png
#   2
# plot without title

# %%
reject_vars <- c("cvo_num_of_output", 
                "cvp_sloc", 
                 "km_dataset_vote_avg"
                )
env_vars <- env_vars[!(env_vars %in% reject_vars)]
data <- data[env_vars]

vcobj = varclus(~ .,
                
                data = data, 
                
                similarity = "spearman",
                
                trans = "abs"
)

pdf(file="correlation2.pdf", width = 11, height = 8.5)
plot(vcobj)
thresh = 0.7
abline (h = 1 - thresh, col = "red", lty = 2)
dev.off()

plot(vcobj)
thresh = 0.7
abline (h = 1 - thresh, col = "red", lty = 2)
# Out:
# png
#   2
# plot without title

# %%
reject_vars <- c("cvo_display_data"
                )
env_vars <- env_vars[!(env_vars %in% reject_vars)]
data <- data[env_vars]

vcobj = varclus(~ .,
                
                data = data, 
                
                similarity = "spearman",
                
                trans = "abs"
)

pdf(file="correlation2.pdf", width = 11, height = 8.5)
plot(vcobj)
thresh = 0.7
abline (h = 1 - thresh, col = "red", lty = 2)
dev.off()

plot(vcobj)
thresh = 0.7
abline (h = 1 - thresh, col = "red", lty = 2)
# Out:
# png
#   2
# plot without title

# %% [markdown]
# ## Second Step is to prepare the dataframe, add the voted column back to dataframe.

# %% [markdown]
# random forest model fitting referece: https://www.blopig.com/blog/2017/04/a-very-basic-introduction-to-random-forests-using-r/

# %% [markdown]
# ### binary classification:

# %%
data_classification = cbind(data, high_voted)

# %%
head(data_classification)
# Out:
#   km_tags_te_avg cvp_comments cvp_iptfrm_te_avg cvp_ipt_te_avg
# 1 0.1838572      37           0.3153332         0.2340785
# 2 0.1838572      36           0.2732372         0.2340785
# 3 0.1838572      66           0.3416692         0.3494732
# 4 0.1838572      44           0.3763483         0.2994463
# 5 0.1838572      56           0.3045886         0.2521930
# 6 0.1838572       8           0.2995782         0.2799080
#   km_dataset_discussion_avg km_competition_size_avg km_isNotebook km_null
# 1 0                             34757               0.2336647     0
# 2 0                             34757               0.2336647     0
# 3 0                                 0               0.2336647     0
# 4 1                                 0               0.2163905     0
# 5 0                          16054448               0.2163905     0
# 6 0                         117366271               0.2336647     0
#   km_Other km_versions cvp_iptfrm_te_min km_Visualization cvp_ipt_te_min
# 1 0         89         0.2286862         0                0.2316358
# 2 0        371         0.0000000         0                0.2316358
# 3 0        766         0.1439689         0                0.2316358
# 4 0          4         0.3557402         3                0.2316358
# 5 0          3         0.1038794         2                0.2316358
# 6 0         30         0.1889055         0                0.2316358
#   cvp_num_of_iptfrm km_Data cvo_error km_dataSources high_voted
# 1  7                1       0         1              False
# 2  3                1       0         1              False
# 3 30                0       0         1              False
# 4  3                0       0         1              False
# 5 10                1       0         1              False
# 6 11                1       0         1              False

# %% [markdown]
# This step is used for generating the binary label.

# %%
summary(data_classification)
# Out:
#  km_tags_te_avg    cvp_comments     cvp_iptfrm_te_avg cvp_ipt_te_avg
#  Min.   :0.0000   Min.   :   0.00   Min.   :0.0000    Min.   :0.0000
#  1st Qu.:0.1839   1st Qu.:   8.00   1st Qu.:0.1039    1st Qu.:0.2341
#  Median :0.1839   Median :  20.00   Median :0.1931    Median :0.2643
#  Mean   :0.2211   Mean   :  48.29   Mean   :0.2388    Mean   :0.2581
#  3rd Qu.:0.1839   3rd Qu.:  66.00   3rd Qu.:0.3290    3rd Qu.:0.2931
#  Max.   :1.0000   Max.   :2765.00   Max.   :1.0000    Max.   :1.0000
#  km_dataset_discussion_avg km_competition_size_avg km_isNotebook
#  Min.   : 0.000            Min.   :0.000e+00       Min.   :0.2164
#  1st Qu.: 0.000            1st Qu.:0.000e+00       1st Qu.:0.2164
#  Median : 0.000            Median :3.476e+04       Median :0.2164
#  Mean   : 3.437            Mean   :7.210e+08       Mean   :0.2188
#  3rd Qu.: 3.000            3rd Qu.:1.605e+07       3rd Qu.:0.2164
#  Max.   :51.000            Max.   :1.026e+11       Max.   :0.2337
#     km_null            km_Other         km_versions       cvp_iptfrm_te_min
#  Min.   :  0.0000   Min.   :0.00e+00   Min.   :   0.000   Min.   :0.0000
#  1st Qu.:  0.0000   1st Qu.:0.00e+00   1st Qu.:   0.000   1st Qu.:0.1039
#  Median :  0.0000   Median :0.00e+00   Median :   1.000   Median :0.1889
#  Mean   :  0.1003   Mean   :7.87e-03   Mean   :   3.706   Mean   :0.1827
#  3rd Qu.:  0.0000   3rd Qu.:0.00e+00   3rd Qu.:   3.000   3rd Qu.:0.2091
#  Max.   :492.0000   Max.   :2.05e+02   Max.   :4046.000   Max.   :1.0000
#  km_Visualization   cvp_ipt_te_min   cvp_num_of_iptfrm    km_Data
#  Min.   :    0.00   Min.   :0.0000   Min.   :  0.000   Min.   :  0.0000
#  1st Qu.:    0.00   1st Qu.:0.2316   1st Qu.:  1.000   1st Qu.:  0.0000
#  Median :    0.00   Median :0.2316   Median :  1.000   Median :  0.0000
#  Mean   :    3.24   Mean   :0.2154   Mean   :  4.007   Mean   :  0.2897
#  3rd Qu.:    2.00   3rd Qu.:0.2316   3rd Qu.:  5.000   3rd Qu.:  0.0000
#  Max.   :32744.00   Max.   :1.0000   Max.   :130.000   Max.   :194.0000
#    cvo_error        km_dataSources   high_voted
#  Min.   :  0.0000   Min.   : 0.000   False:101092
#  1st Qu.:  0.0000   1st Qu.: 1.000   True : 28322
#  Median :  0.0000   Median : 1.000
#  Mean   :  0.2299   Mean   : 1.067
#  3rd Qu.:  0.0000   3rd Qu.: 1.000
#  Max.   :248.0000   Max.   :57.000

# %% [markdown]
# ## Then Divide the training and testing data

# %%
## 75% of the sample size
smp_size <- floor(0.75 * nrow(data_classification))

## set the seed to make your partition reproducible
set.seed(123)
train_ind <- sample(seq_len(nrow(data_classification)), size = smp_size)

train <- data_classification[train_ind, ]
test <- data_classification[-train_ind, ]

# %% [markdown]
# Then we fit the model.

# %%
#import the package
library(randomForest)
# Perform training:
rf_classifier2 = randomForest(as.factor(high_voted) ~ ., data=train, ntree=100, mtry=2, importance=TRUE)
# because of the as.factor(...), randomforest can fit a classification model. 
rf_classifier2
# Out:
# randomForest 4.6-14
# Type rfNews() to see new features/changes/bug fixes.
#
# Attaching package: 'randomForest'
#
# The following object is masked from 'package:ggplot2':
#
#     margin
# Call:
#  randomForest(formula = as.factor(high_voted) ~ ., data = train,      ntree = 100, mtry = 2, importance = TRUE)
#                Type of random forest: classification
#                      Number of trees: 100
# No. of variables tried at each split: 2
#
#         OOB estimate of  error rate: 15.51%
# Confusion matrix:
#       False True class.error
# False 72113 3860  0.05080752
# True  11194 9893  0.53084839

# %%
importance(rf_classifier2, type= 1)
# Out:
#                           MeanDecreaseAccuracy
# km_tags_te_avg            32.467310
# cvp_comments              22.908666
# cvp_iptfrm_te_avg         22.974112
# cvp_ipt_te_avg            32.262383
# km_dataset_discussion_avg 16.687263
# km_competition_size_avg   22.519048
# km_isNotebook             18.096325
# km_null                   13.504486
# km_Other                   3.206304
# km_versions               36.838373
# cvp_iptfrm_te_min         16.824692
# km_Visualization          22.232856
# cvp_ipt_te_min             9.947548
# cvp_num_of_iptfrm         16.041778
# km_Data                   10.352739
# cvo_error                 14.759168
# km_dataSources            17.693266

# %%
pdf(file="importance_for_python_vote_only.pdf", width = 7, height = 7)
varImpPlot(rf_classifier2, type= 1)
dev.off()
# Out:
# png
#   2

# %% [markdown]
# This is AUC. If the stackoverflow gave me the right answer.

# %%
# import the library that needed in calculating the AUC. 
library(pROC)
library(ROCR)
# Out:
# Type 'citation("pROC")' for a citation.
#
# Attaching package: 'pROC'
#
# The following objects are masked from 'package:stats':
#
#     cov, smooth, var
#
# Loading required package: gplots
#
# Attaching package: 'gplots'
#
# The following object is masked from 'package:stats':
#
#     lowess

# %%
# https://stackoverflow.com/questions/46776944/how-to-calculate-randomforest-training-auc-in-r
# the train AUC
rf_p_train <- predict(rf_classifier2, type="prob")[,2]
rf_pr_train <- prediction(rf_p_train, train$high_vote)
r_auc_train <- performance(rf_pr_train, measure = "auc")@y.values[[1]] 
r_auc_train
# Out:
# [1] 0.8687072

# %%
#https://stats.stackexchange.com/questions/308645/why-does-randomforest-has-higher-test-auc-than-train-auc-is-this-possible
#the test AUC
rf_p_test <- predict(rf_classifier2, type="prob", newdata = test)[,2]
rf_pr_test <- prediction(rf_p_test, test$high_vote)
r_auc_test <- performance(rf_pr_test, measure = "auc")@y.values[[1]] 
r_auc_test
# Out:
# [1] 0.8741364

# %% [markdown]
# ### Logistic Regression

# %%
library(rms)
fit <- lrm(high_voted ~ .,
           data=train, x=T, y=T)

# %%
val <- validate(fit, B=1000)
AUC = 0.5 + val[1,1]/2
AUC_optimism_reduced = (0.5 + val[1,5]/2)
AUC_optimism = AUC - AUC_optimism_reduced
print(c("AUC"=AUC,"AUC_optimism"=AUC_optimism))
# Out:
#          AUC AUC_optimism
# 0.6434512055 0.0009310391
