# %% [markdown]
# ## Exploratory Data Analysis (EDA)
#
# https://tianchi.aliyun.com/notebook-ai/detail?spm=5176.12586969.1002.3.3b30b135yt4vF1&postId=129320

# %%
import pandas as pd
import numpy as np
# %matplotlib inline
import matplotlib.pyplot as plt
# import matplotlib.pyplot as plt
import seaborn as sns
import datetime
import warnings
warnings.filterwarnings('ignore')

# %%
data_train = pd.read_csv('originalDataset/train.csv')
data_test_a = pd.read_csv('originalDataset/testA.csv')

# %% [markdown]
# Object: category type data?
#
# I don't think it is precise judgement. Refer to this page: https://blog.csdn.net/a8131357leo/article/details/79635866 . Seems that string type data's dtype is `object`

# %%
data_train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 800000 entries, 0 to 799999
# Data columns (total 47 columns):
#  #   Column              Non-Null Count   Dtype
# ---  ------              --------------   -----
#  0   id                  800000 non-null  int64
#  1   loanAmnt            800000 non-null  float64
#  2   term                800000 non-null  int64
#  3   interestRate        800000 non-null  float64
#  4   installment         800000 non-null  float64
#  5   grade               800000 non-null  object
#  6   subGrade            800000 non-null  object
#  7   employmentTitle     799999 non-null  float64
#  8   employmentLength    753201 non-null  object
#  9   homeOwnership       800000 non-null  int64
#  10  annualIncome        800000 non-null  float64
#  11  verificationStatus  800000 non-null  int64
#  12  issueDate           800000 non-null  object
#  13  isDefault           800000 non-null  int64
#  14  purpose             800000 non-null  int64
# ...

# %%
data_train.head(3).append(data_train.tail(3))
# Out:
#             id  loanAmnt  term  interestRate  installment grade subGrade  \
# 0            0   35000.0     5         19.52       917.97     E       E2
# 1            1   18000.0     5         18.49       461.90     D       D2
# 2            2   12000.0     5         16.99       298.17     D       D3
# 799997  799997    6000.0     3         13.33       203.12     C       C3
# 799998  799998   19200.0     3          6.92       592.14     A       A4
# 799999  799999    9000.0     3         11.06       294.91     B       B3
#
#         employmentTitle employmentLength  homeOwnership  ...    n5    n6  \
# 0                 320.0          2 years              2  ...   9.0   8.0
# 1              219843.0          5 years              0  ...   NaN   NaN
# 2               31698.0          8 years              0  ...   0.0  21.0
# 799997           2582.0        10+ years              1  ...   4.0  26.0
# 799998            151.0        10+ years              0  ...  10.0   6.0
# ...

# %% [markdown]
# Select data types. Seems that we can use `data_train.select_xxxx` to define the choice logic?
#
# No. According to code auto-complete result, there is only one `select_xxx` which is `select_dtypes`.

# %%
numerical_fea = list(data_train.select_dtypes(exclude=['object']).columns)
category_fea = list(filter(lambda x: x not in numerical_fea,list(data_train.columns)))

# %%
numerical_fea
# Out:
# ['id',
#  'loanAmnt',
#  'term',
#  'interestRate',
#  'installment',
#  'employmentTitle',
#  'homeOwnership',
#  'annualIncome',
#  'verificationStatus',
#  'isDefault',
#  'purpose',
#  'postCode',
#  'regionCode',
#  'dti',
#  'delinquency_2years',
#  'ficoRangeLow',
#  'ficoRangeHigh',
#  'openAcc',
#  'pubRec',
#  'pubRecBankruptcies',
#  'revolBal',
#  'revolUtil',
#  'totalAcc',
#  'initialListStatus',
#  'applicationType',
#  'title',
#  'policyCode',
#  'n0',
#  'n1',
#  'n2',
#  'n3',
#  'n4',
#  'n5',
#  'n6',
#  'n7',
#  'n8',
#  'n9',
#  'n10',
#  'n11',
#  'n12',
#  'n13',
#  'n14']

# %%
category_fea
# Out:
# ['grade', 'subGrade', 'employmentLength', 'issueDate', 'earliesCreditLine']

# %% [markdown]
# `Numerical type data` is separated from `categorical type data`.
#
# But `Numerical type data` needs to be devided into `continuous`(`serial`) and `discrete`(`nonserial`) types.

# %%
def get_numerical_serial_fea(data,feas):
    numerical_serial_fea = []
    numerical_noserial_fea = []
    for fea in feas:
        temp = data[fea].nunique()
        if temp <= 10:
            numerical_noserial_fea.append(fea)
            continue
        numerical_serial_fea.append(fea)
    return numerical_serial_fea,numerical_noserial_fea

numerical_serial_fea,numerical_noserial_fea = get_numerical_serial_fea(data_train,numerical_fea)

# %% [markdown]
# How to use `pd.melt()` seems cool.
#
# https://vimsky.com/examples/usage/python-pandas-melt.html

# %%
f = pd.melt(data_train, value_vars=numerical_serial_fea)

# %% [markdown]
# sun.FaceGrid: https://zhuanlan.zhihu.com/p/27816821

# %%
g = sns.FacetGrid(f, col="variable",  col_wrap=2, sharex=False, sharey=False)

# %% [markdown]
# sns.displot: https://www.cnblogs.com/gczr/p/10354491.html

# %%
g = g.map(sns.distplot, "value")
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-17-9323d084b98b> in <module>
# ----> 1 g = g.map(sns.distplot, "value")
#
# ~/anaconda3/lib/python3.7/site-packages/seaborn/axisgrid.py in map(self, func, *args, **kwargs)
#     741
#     742             # Get the current axis
# --> 743             ax = self.facet_axis(row_i, col_j)
#     744
#     745             # Decide what color to plot with
#
# ~/anaconda3/lib/python3.7/site-packages/seaborn/axisgrid.py in facet_axis(self, row_i, col_j)
#     871
#     872         # Get a reference to the axes object we want, and make it active
# --> 873         plt.sca(ax)
#     874         return ax
#     875
#
# ~/anaconda3/lib/python3.7/site-packages/matplotlib/pyplot.py in sca(ax)
#     903             m.canvas.figure.sca(ax)
#     904             return
# ...

# %% [markdown]
# Process the date. Seems that the date generated by `pd.to_datetime` is the same as python library: `datetime`.

# %%
data_train['issueDate'] = pd.to_datetime(data_train['issueDate'],format='%Y-%m-%d')
startdate = datetime.datetime.strptime('2007-06-01', '%Y-%m-%d')
data_train['issueDateDT'] = data_train['issueDate'].apply(lambda x: x-startdate).dt.days

# %% [markdown]
# `pd.pivout_table` looks similar to `groupby`, but it is more flexible.
# https://zhuanlan.zhihu.com/p/31952948

# %%
pivot = pd.pivot_table(data_train, index=['grade'], columns=['issueDateDT'], values=['loanAmnt'], aggfunc=np.sum)

# %%
pivot
# Out:
#             loanAmnt                                                         \
# issueDateDT     0        30       61       92       122      153       183
# grade
# A                NaN  53650.0  42000.0  19500.0  34425.0  63950.0   43500.0
# B                NaN  13000.0  24000.0  32125.0   7025.0  95750.0  164300.0
# C                NaN  68750.0   8175.0  10000.0  61800.0  52550.0  175375.0
# D                NaN      NaN   5500.0   2850.0  28625.0      NaN  167975.0
# E             7500.0      NaN  10000.0      NaN  17975.0   1500.0   94375.0
# F                NaN      NaN  31250.0   2125.0      NaN      NaN       NaN
# G                NaN      NaN      NaN      NaN      NaN      NaN       NaN
#
#                                            ...                          \
# issueDateDT      214       245       274   ...        3926        3957
# grade                                      ...
# A            168825.0   85600.0  101825.0  ...  13093850.0  11757325.0
# ...

# %% [markdown]
# `pandas_profilling` is great. Summarize the data, very awesome.
# https://zhuanlan.zhihu.com/p/47548106

# %%
# !pip install pandas_profiling
import pandas_profiling
pfr = pandas_profiling.ProfileReport(data_train)
pfr.to_file("./example.html")

# %%
# Out:
# ...
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# <ipython-input-21-aa1d74842586> in <module>
#       1 pfr = pandas_profiling.ProfileReport(data_train)
# ----> 2 pfr.to_file("./example.html")
#
# ~/anaconda3/lib/python3.7/site-packages/pandas_profiling/profile_report.py in to_file(self, output_file, silent)
#     254                 create_html_assets(output_file)
#     255
# --> 256             data = self.to_html()
#     257
#     258             if output_file.suffix != ".html":
#
# ~/anaconda3/lib/python3.7/site-packages/pandas_profiling/profile_report.py in to_html(self)
#     357
#     358         """
# --> 359         return self.html
#     360
#     361     def to_json(self) -> str:
#
# ~/anaconda3/lib/python3.7/site-packages/pandas_profiling/profile_report.py in html(self)
#     177     def html(self):
#     178         if self._html is None:
# ...
