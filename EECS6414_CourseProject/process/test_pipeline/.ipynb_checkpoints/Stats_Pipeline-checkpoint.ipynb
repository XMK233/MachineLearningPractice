# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

def describe_a_data_frame(file_path, features_dont_want_to_see = []):
    stats = pd.read_csv(file_path)
    for i in list(stats.columns.values):
        if i in features_dont_want_to_see:
            continue
        print(i)
        stats[i] = pd.to_numeric(stats[i])
        print("information about {}. \n".format(i), stats[i].describe(), "\n\n")

def load_plot_describe(data_cluster, qntl, plot_title = ""):
    res = data_cluster
    res_origin = res
    res = np.log([x+0.1 for x in res])
    #res = np.log(res)  

    fig1, ax1 = plt.subplots(figsize=(8, 10))
    if plot_title != "":
        ax1.set_title(plot_title)
    ax1.boxplot(res)
    #fig1.savefig(file_dir + ".pdf")
    plt.show()

    from scipy import stats
    print(stats.describe(res_origin))

    # for median ...
    print("median: ", np.median(res_origin))

    # also count 25% quantile 75% quantile ,etc.
    print("quantile x10%", np.quantile(res_origin, [0.1 * k for k in range(qntl)]))

# %%
kernel_stats = pd.read_csv("C:\\Users\\xmk233\\PycharmProjects\\EECS6414\\process\\test_pipeline\\TEST_DATASET2\\stats\\kernel_stats.csv")

for i in list(kernel_stats.columns.values):
    if i == "source1st" or i == "sourceType1st" or i == "kernel" or i == "author":
        continue
    print(i)
    kernel_stats[i] = pd.to_numeric(kernel_stats[i])
    print("information about {}. \n".format(i), kernel_stats[i].describe(), "\n\n")
# Out:
# datasets
# information about datasets.
#  count    24662.000000
# mean         1.165599
# std          0.899961
# min          0.000000
# 25%          1.000000
# 50%          1.000000
# 75%          1.000000
# max         58.000000
# Name: datasets, dtype: float64
#
#
# versions
# information about versions.
#  count    24662.000000
# mean        11.538845
# std         36.769572
# min          0.000000
# 25%          2.000000
# 50%          5.000000
# 75%         11.000000
# max       4046.000000
# Name: versions, dtype: float64
#
#
# forks
# information about forks.
#  count    24662.000000
# mean        57.509123
# std        903.101671
# min          0.000000
# 25%          0.000000
# 50%          3.000000
# 75%         10.000000
# max      69026.000000
# Name: forks, dtype: float64
#
#
# comments
# information about comments.
#  count    24662.000000
# mean         4.119414
# std         18.072343
# min          0.000000
# 25%          0.000000
# 50%          0.000000
# 75%          3.000000
# max        911.000000
# Name: comments, dtype: float64
#
#
# views
# information about views.
#  count    2.466200e+04
# mean     1.909306e+03
# std      1.139771e+04
# min      0.000000e+00
# 25%      1.130000e+02
# 50%      3.530000e+02
# 75%      1.162000e+03
# max      1.139069e+06
# Name: views, dtype: float64
#
#
# votes
# information about votes.
#  count    24662.000000
# mean        15.268997
# std         72.103283
# min          0.000000
# 25%          2.000000
# 50%          3.000000
# 75%          9.000000
# max       3535.000000
# Name: votes, dtype: float64

# %%
kernel_stats.head()
# Out:
#                              kernel     author  datasets  \
# 0                    team-engineers     a13579         1
# 1    bayesian-optimization-lightgbm  a31314431         1
# 2  another-graph-dashboard-approach     a45632         1
# 3      classification-tfidf-svm-2-0     a45632         1
# 4       hyperrealistic-dataset-view     a45632         1
#
#                                 source1st sourceType1st  versions  forks  \
# 0                       absenteeismatwork       dataset         5      1
# 1  talkingdata-adtracking-fraud-detection   competition         7     26
# 2                     seattle-crisis-data       dataset         1      0
# 3      20-newsgroups-ciphertext-challenge   competition         3      7
# 4              whats-cooking-kernels-only   competition         1      0
#
#    comments  views  votes
# 0         0     99      1
# 1         4   3876     17
# 2         0     22      2
# 3         3    268      5
# 4         1     60      1

# %%
data_cluster = []
for index, row in kernel_stats.iterrows():
    data_cluster.append(int(row["versions"]))
load_plot_describe(data_cluster, 9, "kernel and commits")
# Out:
# DescribeResult(nobs=24662, minmax=(0, 4046), mean=11.538845186927256, variance=1352.0013903049721, skewness=59.794613696634656, kurtosis=6016.409292757706)
# median:  5.0
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-15-d8f1f94bc0cf> in <module>()
#      27     # also count 25% quantile 75% quantile ,etc.
#      28     print("quantile x10%", np.quantile(res_origin, [0.1 * k for k in range(qntl)]))
# ---> 29 load_plot_describe(data_cluster, 9, "kernel and commits")
#
# <ipython-input-15-d8f1f94bc0cf> in load_plot_describe(data_cluster, qntl, plot_title)
#      26
#      27     # also count 25% quantile 75% quantile ,etc.
# ---> 28     print("quantile x10%", np.quantile(res_origin, [0.1 * k for k in range(qntl)]))
#      29 load_plot_describe(data_cluster, 9, "kernel and commits")
#
# AttributeError: module 'numpy' has no attribute 'quantile'

# %%
dataset_stats = pd.read_csv("C:\\Users\\xmk233\\PycharmProjects\\EECS6414\\process\\test_pipeline\\TEST_DATASET2\\stats\\dataset_stats.csv")

for i in list(dataset_stats.columns.values):
    if i == "dataset" or i == "author":
        continue
    print(i)
    dataset_stats[i] = pd.to_numeric(dataset_stats[i])
    print("information about {}. \n".format(i), dataset_stats[i].describe(), "\n\n")
# Out:
# size
# information about size.
#  count    1.972000e+03
# mean     3.286749e+09
# std      6.721750e+10
# min      1.870000e+02
# 25%      6.603325e+04
# 50%      1.189732e+06
# 75%      2.584933e+07
# max      2.610000e+12
# Name: size, dtype: float64
#
#
# discussions
# information about discussions.
#  count    1972.000000
# mean        1.582657
# std         4.286631
# min         0.000000
# 25%         0.000000
# 50%         0.000000
# 75%         1.000000
# max        88.000000
# Name: discussions, dtype: float64
#
#
# kernels
# information about kernels.
#  count    1972.000000
# mean       39.128296
# std       157.453712
# min         1.000000
# 25%         2.000000
# 50%         4.000000
# 75%        16.250000
# max      3659.000000
# Name: kernels, dtype: float64
#
#
# downloads
# information about downloads.
#  count     1972.000000
# mean      2051.220588
# std       5672.133359
# min          0.000000
# 25%         48.000000
# 50%        371.000000
# 75%       1611.500000
# max      98617.000000
# Name: downloads, dtype: float64
#
#
# views
# information about views.
#  count    1.972000e+03
# mean     1.515767e+04
# std      5.121735e+04
# min      1.000000e+01
# 25%      4.497500e+02
# 50%      3.215000e+03
# 75%      1.335025e+04
# max      1.685676e+06
# Name: views, dtype: float64
#
#
# vote
# information about vote.
#  count    1972.000000
# mean       51.263185
# std       131.537419
# min         0.000000
# 25%         1.000000
# 50%        11.000000
# 75%        43.000000
# max      2522.000000
# Name: vote, dtype: float64
#
#
# version
# information about version.
#  count    1972.000000
# mean        4.427485
# std        19.629762
# min         1.000000
# 25%         1.000000
# 50%         1.000000
# 75%         2.000000
# max       400.000000
# Name: version, dtype: float64

# %%
describe_a_data_frame("C:\\Users\\xmk233\\PycharmProjects\\EECS6414\\process\\test_pipeline\\TEST_DATASET2\\stats\\competition_stats.csv", 
                     ["competition", "organization"])
# Out:
# size
# information about size.
#  count    2.160000e+02
# mean     2.662326e+09
# std      1.066109e+10
# min      0.000000e+00
# 25%      2.238479e+06
# 50%      3.449149e+07
# 75%      4.738207e+08
# max      1.026039e+11
# Name: size, dtype: float64
#
#
# discussion
# information about discussion.
#  count     216.000000
# mean      104.101852
# std       137.093072
# min         0.000000
# 25%        12.750000
# 50%        66.000000
# 75%       148.500000
# max      1300.000000
# Name: discussion, dtype: float64
#
#
# competitors
# information about competitors.
#  count      216.000000
# mean      1289.310185
# std       1516.425838
# min          0.000000
# 25%        193.750000
# 50%        764.500000
# 75%       1850.000000
# max      10218.000000
# Name: competitors, dtype: float64

# %%
describe_a_data_frame("C:\\Users\\xmk233\\PycharmProjects\\EECS6414\\process\\test_pipeline\\TEST_DATASET2\\stats\\author_stats.csv", 
                     ["author"])
# Out:
# competition
# information about competition.
#  count    3240.000000
# mean        4.698765
# std        10.716101
# min         0.000000
# 25%         0.000000
# 50%         1.000000
# 75%         5.000000
# max       146.000000
# Name: competition, dtype: float64
#
#
# cmp_tier
# information about cmp_tier.
#  count    3240.000000
# mean        1.813272
# std         0.809032
# min         1.000000
# 25%         1.000000
# 50%         2.000000
# 75%         2.000000
# max         5.000000
# Name: cmp_tier, dtype: float64
#
#
# kernel
# information about kernel.
#  count    3240.000000
# mean        7.191667
# std        22.707966
# min         0.000000
# 25%         1.000000
# 50%         3.000000
# 75%         7.000000
# max       855.000000
# Name: kernel, dtype: float64
#
#
# scpt_tier
# information about scpt_tier.
#  count    3240.000000
# mean        1.717901
# std         0.637454
# min         1.000000
# 25%         1.000000
# 50%         2.000000
# 75%         2.000000
# max         5.000000
# Name: scpt_tier, dtype: float64
#
#
# discussion
# information about discussion.
#  count    3240.000000
# mean       33.763580
# std       133.593679
# min         0.000000
# 25%         1.000000
# 50%         5.000000
# 75%        19.000000
# max      3958.000000
# Name: discussion, dtype: float64
#
#
# dsc_tier
# information about dsc_tier.
#  count    3240.000000
# mean        1.696914
# std         0.605208
# min         1.000000
# 25%         1.000000
# 50%         2.000000
# 75%         2.000000
# max         5.000000
# Name: dsc_tier, dtype: float64
#
#
# follower
# information about follower.
#  count    3240.000000
# mean       19.611111
# std       125.918962
# min         0.000000
# 25%         0.000000
# 50%         1.000000
# 75%         5.000000
# max      2743.000000
# Name: follower, dtype: float64
#
#
# following
# information about following.
#  count    3240.000000
# mean        5.029321
# std        16.031925
# min         0.000000
# 25%         0.000000
# 50%         1.000000
# 75%         4.000000
# max       376.000000
# Name: following, dtype: float64
