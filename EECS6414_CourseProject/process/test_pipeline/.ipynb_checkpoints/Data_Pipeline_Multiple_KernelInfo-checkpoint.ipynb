# %% [markdown]
# # This is a pipeline for parsing multiple KernelInfo files.

# %% [markdown]
# # Exclude Kerneler

# %%
# -*- coding: utf-8 -*-
import sys, os, json
DATA_STORE = "J:\\EECS_6414\\Data\\TEST_DATASET1"
DATA_SOURCE = "J:\\EECS_6414\\Data\\19-02-03"
available_file_number = [i for i in range(13)]#
available_file_number.extend([21, 22, 23, 31, 32, 33, 34, 35])

kernel_ids = []
counter = 0
limit = 3
for fn in available_file_number:
    print(os.path.join(DATA_SOURCE, "KernelInfo_{}.json".format(fn)))
    with open(os.path.join(DATA_SOURCE, "KernelInfo_{}.json".format(fn)), "r") as f:
        kernels = json.load(f)
    for kernel in kernels:
        value = kernel["info"]
        if value["author"]["displayName"] == "Kaggle Kerneler":
            continue
        kernel_ids.append(kernel)
        # counter+=1

with open(os.path.join(DATA_STORE, "combined_v1.json"), "w") as f:
    kernels = json.dump(kernel_ids, f)
print(len(kernel_ids))
# Out:
# J:\EECS_6414\Data\19-02-03\KernelInfo_0.json
# J:\EECS_6414\Data\19-02-03\KernelInfo_1.json
# J:\EECS_6414\Data\19-02-03\KernelInfo_2.json
# J:\EECS_6414\Data\19-02-03\KernelInfo_3.json
# J:\EECS_6414\Data\19-02-03\KernelInfo_4.json
# J:\EECS_6414\Data\19-02-03\KernelInfo_5.json
# J:\EECS_6414\Data\19-02-03\KernelInfo_6.json
# J:\EECS_6414\Data\19-02-03\KernelInfo_7.json
# J:\EECS_6414\Data\19-02-03\KernelInfo_8.json
# J:\EECS_6414\Data\19-02-03\KernelInfo_9.json
# J:\EECS_6414\Data\19-02-03\KernelInfo_10.json
# J:\EECS_6414\Data\19-02-03\KernelInfo_11.json
# J:\EECS_6414\Data\19-02-03\KernelInfo_12.json
# J:\EECS_6414\Data\19-02-03\KernelInfo_21.json
# J:\EECS_6414\Data\19-02-03\KernelInfo_22.json
# J:\EECS_6414\Data\19-02-03\KernelInfo_23.json
# J:\EECS_6414\Data\19-02-03\KernelInfo_31.json
# J:\EECS_6414\Data\19-02-03\KernelInfo_32.json
# J:\EECS_6414\Data\19-02-03\KernelInfo_33.json
# J:\EECS_6414\Data\19-02-03\KernelInfo_34.json
# J:\EECS_6414\Data\19-02-03\KernelInfo_35.json
# 3511

# %% [markdown]
# # get files of kernels for this pipeline

# %%
# -*- coding: utf-8 -*-
import json, os, shutil
json_path = "J:\\EECS_6414\\Data\\TEST_DATASET1\\combined_v1.json"
file_from = "J:\\EECS_6414\\Data\\19-02-03\\files"
file_to = "J:\EECS_6414\Data\TEST_DATASET1\\files"
if not os.path.exists(file_to):
    os.makedirs(file_to)
with open(json_path, "r") as j:
    kernels = json.load(j)
for kernel in kernels:
    title = kernel["title"]
    ###############
    ## sometimes there is something wrong in it. 
    ###############
    try: 
        shutil.copytree(os.path.join(file_from, title),
                       os.path.join(file_to, title))
    except:
        pass
print("хорошо ok")
# Out:
# хорошо ok

# %% [markdown]
# # Download Authors and Datasets from Kaggle using Spider in "crawler"
# * I don't know why, only 1 item in all of the 2 will be download. Whatever, this is not the top concern now.
# * 2019年2月9日 in terms of the result I got now, I can say that the author gathering is OK now.

# %% [markdown]
# # Move the author and dataset to Test Directory

# %% [markdown]
# * Don't worry. Take it easy.

# %%
json_path = "J:\\EECS_6414\\Data\\TEST_DATASET1\\combined_v1.json"

author_path = "J:\\EECS_6414\\Data\\19-02-03\\test_pages\\author_pages"
target_author_path = "J:\\EECS_6414\\Data\\TEST_DATASET1\\author_pages"
dataset_path = "J:\\EECS_6414\\Data\\19-02-03\\test_pages\\dataset_pages"
target_dataset_path = "J:\\EECS_6414\\Data\\TEST_DATASET1\\dataset_pages"

with open(json_path, "r") as j:
    kernels = json.load(j)
authorUrls = []
datasetUrls = []
for kernel in kernels:
    info = kernel["info"]
    title = kernel["title"]

    #item = OverallDownload()
    authorUrls.append(info["author"]["profileUrl"])
    datasetUrls.extend([ds["dataSourceUrl"] for ds in info["dataSources"] if ds is not None])

authorUrls = list(set(authorUrls))
print("author urls. this number is approximate: ", len(authorUrls))
datasetUrls = list(set(datasetUrls))
print("dataset urls. this number is approximate: ", len(datasetUrls))
# Out:
# author urls. this number is approximate:  1625
# dataset urls. this number is approximate:  1086

# %%
print(authorUrls)
# Out:
# ['/romanpopat', '/donchuk', '/colinmorris', '/abriosi', '/angps95', '/operdeck', '/jannen', '/samstiyer', '/ogrellier', '/avehtari', '/little7', '/mlisovyi', '/ldm314', '/go1dfish', '/jasonm', '/kanncaa1', '/sanjaym0410', '/jamesrequa', '/michelnzikou', '/kunstmord', '/mahbubrob', '/doctorclo', '/fuzzywizard', '/agrigorev', '/sheriytm', '/tanitter', '/rafjaa', '/kueipo', '/aboliveira', '/hugorcf', '/lextoumbourou', '/iafoss', '/mrwolfgang', '/xhlulu', '/shubh24', '/janiobachmann', '/strivingwen', '/victorgrobberio', '/sebastianmantey', '/danjordan', '/naresh31', '/tqchen', '/shreyask92', '/yuqingxue', '/kretes', '/jboysen', '/skramer', '/davidunknown', '/nulldata', '/abhishekheads', '/mikhailhushchyn', '/hely333', '/blacksix', '/yuriicojocari', '/seesee', '/sudhirnl7', '/olgabelitskaya', '/rajnish7k', '/stefanogizmo', '/guoday', '/eddfung', '/minhtriet', '/asmasem', '/tini9911', '/chabir', '/nadintamer', '/mpearmain', '/mabrek', '/sekrier', '/nschneider', '/daveianhickey', '/ayoubchebbi', '/lemonkoala', '/tensor2flow', '/davero', '/arthurlu', '/giuliasavorgnan', '/emilaye', '/darraghdog', '/vicensgaitan', '/cbourguignat', '/zeroblue', '/truocpham', '/mrisdal', '/jriskas', '/bhaveshthaker', '/loisso', '/rshally', '/ianchute', '/victorhz', '/adrian1acoran', '/niklasdonges', '/zfturbo', '/nzw0301', '/nikitaromanov', '/lopuhin', '/javierbravo', '/strakul5', '/fruitvul', '/abdullahcakmak', '/niclasko', '/apryor6', '/serkanpeldek', '/sflender', '/razarocket', '/astrus', '/rsmits', '/mosnoiion', '/etatbak', '/mistrzuniu1', '/vpaslay', '/meetnaren
buzz/textcnn-2d-convolution-on-preprocessed-data', '/dansbecker/new-york-city-taxi-fare-prediction', '/bedykharisma/country-profile', '/prashantkikani/toxicfiles', '/demesgal/lstm-glove-lr-decrease-bn-cv-lb-0-047', '/transparencyint/corruption-index', '/c/dog-breed-identification', '/moltean/fruits', '/ash316/usa-zip-codes-to-locations', '/new-york-city/ny-school-attendance-and-enrollment', '/uciml/sms-spam-collection-dataset', '/jacobbaruch/nba-player-of-the-week', '/gopisaran/all-images', '/sid321axn/amazon-alexa-reviews', '/kmader/rsna-bone-age', '/mchirico/philadelphiacrimedata', '/uciml/glass', '/aruchomu/data-for-yolo-v3-kernel', '/jayavardhanr/glove-vectors', '/crailtap/street-network-of-new-york-in-graphml', '/tamber/steam-video-games', '/sohinibhattacharya86/train-rdcsv', '/willkoehrsen/hom ...

# %%
#############################
### I don't know why there is 
### some file missing. 
#############################

for a in authorUrls: 
    a_ = a.replace("/", "") + ".html"
    try:
        shutil.copy(
            os.path.join(author_path, a_), 
            os.path.join(target_author_path, a_)
        )
    except:
        pass

for d in datasetUrls: 
    if d is None:
        continue
    d_ = d.replace("/", "_")[1:] + ".html"
    #print(d_)
    try: 
#         print(d_)
        shutil.copy(
            os.path.join(dataset_path, d_), 
            os.path.join(target_dataset_path, d_)
        )
    except:
        pass
# Out:
# calmdownkarm_ufcdataset.html
# gaborfodor_metacover.html
# ceshine_pytorch-baseline-model.html
# c_grupo-bimbo-inventory-demand.html
# ahmedelnaggar_fifa-worldcup-2018-dataset.html
# fkosmowski_kivadhsv1.html
# gaborfodor_externalnfl.html
# vjchoudhary7_customer-segmentation-tutorial-in-python.html
# achyutanandaparida_dataset from  house sales in king county, usa.html
# mcdonalds_nutrition-facts.html
# neelshah18_arxivdataset.html
# c_kkbox-churn-prediction-challenge.html
# koki25ando_tabelog-restaurant-review-dataset.html
# open-aq_openaq.html
# stackoverflow_stack-overflow-tag-network.html
# aharless_td-backward-time-deltas-as-csv.html
# isaaclayton_20172018-shsat-admissions-test-offers.html
# antgoldbloom_2016-kitefoil-race-results.html
# nsharan_h-1b-visa.html
# c_nomad2018-predict-transparent-conductors.html
# zazueta_pisa-scores-2015.html
# aashita_masks.html
# pvlima_pretrained-pytorch-models.html
# c_march-machine-learning-mania-2016.html
# kmader_transfer-learning-for-boat-or-no-boat.html
# gbletsch_mental-health-in-tech-2014.html
# reppic_pretrained-weights-for-inc-angle.html
# sudalairajkumar_undata-country-profiles.html
# netflix-inc_netflix-prize-data.html
# lazyjustin_pubgplayerstats.html
# dillsunnyb11_digit-recognizer.html
# nobelfoundation_nobel-laureates.html
# jsylas_mobilenet-lb-0-900-forked-from-beluga.html
# residentmario_ramen-ratings.html
# jpmiller_nfl-data-preparation.html
# milesh1_35-million-chess-games.html
# gaborfodor_surveykernelexternals.html
# thec03u5_fifa-18-demo-player-dataset.html
# PythonforSASUsers_hpindex.html
# c_home-credit-default-risk.html
# vprokopev_targetencodingsdata.html
# dongxu027_statoil-iceberg-submissions.html
# mrisdal_2016-us-presidential-debates.html
# olistbr_brazilian-ecommerce.html
# rajmehra03_movielens100k.html
# dansbecker_aer-credit-card-data.html
# fivethirtyeight_fivethirtyeight.html
# theworldbank_procurement-notices.html
# kanncaa1_top-23-user-in-kernel-ranking.html
# martinpiotte_humpback-whale-identification-fluke-location.html
# c_imaterialist-challenge-fashion-2018.html
# timolee_spreadsheet-photo.html
# stackoverflow_so-survey-2017.html
# muonneutrino_new-york-city-census-data.html
# c_new-york-city-taxi-fare-prediction.html
# abhishekmamidi_air-passengers.html
# imrandude_olivetti.html
# uciml_adult-census-income.html
# jordangoblet_atp-tour-20002016.html
# umichigan_world-religions.html
# c_recruit-restaurant-visitor-forecasting.html
# uciml_mushroom-classification.html
# primaryobjects_voicegender.html
# sohinibhattacharya86_corporitasampled-train-data.html
# ogrellier_porto-seguros-safe-driver-noisy-features.html
# discdiver_deep-learning-power-score-data.html
# c_intel-mobileodt-cervical-cancer-screening.html
# joniarroba_noshowappointments.html
# prashantkikani_pooled-gru-with-preprocessing.html
# c_2018 Travelers Statistical Modeling Competition.html
# jsaguiar_pseudo-k-opt.html
# reddit_reddit-comments-may-2015.html
# ronitf_heart-disease-uci.html
# c_two-sigma-financial-news.html
# sterby_fasttext-like-baseline-with-keras-lb-0-053.html
# theworldbank_world-development-indicators.html
# pytorch_resnet34.html
# iafoss_pytorch-pretrained-models.html
# muonneutrino_us-census-demographic-data.html
# c_two-sigma-connect-rental-listing-inquiries.html
# shivamb_external-context.html
# crowdflower_first-gop-debate-twitter-sentiment.html
# brookewatson_worldbank-subnational-poverty.html
# nulldata_udpipe-english-model-pretrained.html
# chadalee_country-wise-population-data.html
# tmdb_tmdb-movie-metadata.html
# c_womens-machine-learning-competition-2018.html
# ramamet4_app-store-apple-data-set-10k-apps.html
# crawford_1000-cameras-dataset.html
# pavanraj159_countries.html
# ramirobentes_flights-in-brazil.html
# rtatman_deceptive-opinion-spam-corpus.html
# bigquery_bitcoin-blockchain.html
# wesamelshamy_google-image-recognition-tutorial.html
# c_otto-group-product-classification-challenge.html

# %% [markdown]
# # Parse Author

# %% [markdown]
# * 这个脚本里面的东西还算靠谱。可以改进。This script is relatively complete. You can furtherly work on this.

# %%
import json, os, shutil, re
from lxml import etree

Author_path = "J:\\EECS_6414\\Data\\TEST_DATASET1\\author_pages"
csv_file = "J:\\EECS_6414\\Data\\TEST_DATASET1\\author_stats.csv"
c = open(csv_file, "w")
c.write("author,competition,cmp_tier,kernel,scpt_tier,discussion,dsc_tier,follower,following\n")
counter = 0

for page_name in os.listdir(Author_path):
    author = page_name.split(".")[0]
    with open(os.path.join(Author_path, page_name), "r", encoding="utf-8") as f:
        html = f.read()
    page_source = etree.HTML(html)
    ###########
    # this part is for dealing with the problem
    # of: too many request.
    # we have to abondon those "too many requests" pages temprarily.
    ###########
    if page_source.xpath("/html/body/pre/text()") != []:
        continue
    ############
    _ = page_source.xpath("//div[@class='site-layout__main-content']/script[1]/text()")[0]
    p = re.compile("Kaggle\.State\.push\(\{[\s\S]*\}\)\;")
    try:
        s = p.findall(_)[0].replace("Kaggle.State.push(", "")[0:-2]
        info = json.loads(s)
    except:
        ##############################
        # this place occurs because
        # we will fail to crawl such information
        ##############################
        print("{} failed: such information cannot be parsed".format(author))

    c.write("{},{},{},{},{},{},{},{},{}\n".format(
        info["userName"],
        info["competitionsSummary"]["totalResults"],info["competitionsSummary"]["tier"],
        info["scriptsSummary"]["totalResults"],info["scriptsSummary"]["tier"],
        info["discussionsSummary"]["totalResults"],info["discussionsSummary"]["tier"],
        info["followers"]["count"], info["following"]["count"]
        ).replace("novice", "1").replace("contributor", "2").replace("expert", "3").replace("grandmaster", "5").replace("master", "4")                                                    
    )
c.close()
print("хорошо, total number is: {}".format(counter))
# Out:
# хорошо, total number is: 0

# %% [markdown]
# # Parse Dataset

# %% [markdown]
# * 2019年2月10日. This is OK now. Can be further modified.

# %%
import json, os, shutil, re
from lxml import etree
from tqdm import tqdm

def get_ajax_json(parameter, page_size):
    # parameter is the parameter of json url.
    # it looks like "&competition=9988"
    import requests
    num = 0
    url = "https://www.kaggle.com/kernels.json?sortBy=hotness&group=everyone{}&pageSize={}".format(parameter,page_size)
    next_url = url
    while True:
        r = requests.get(next_url,
                         auth=('user', 'pass')).json()
        if len(r) == 0:
            break
        elif len(r) > 0 and len(r) < page_size:
            num += len(r)
            break
        else:
            num += len(r)
            last_id = r[len(r) - 1]["id"]
            next_url = url + "&after={}".format(last_id)
    return num

Author_path = "J:\\EECS_6414\\Data\\TEST_DATASET1\\dataset_pages"
competition_file = "J:\\EECS_6414\\Data\\TEST_DATASET1\\competition_stats.csv"
dataset_file = "J:\\EECS_6414\\Data\\TEST_DATASET1\\dataset_stats.csv"
c = open(competition_file, "w", encoding="utf-8")
c.write("competition,organization,size,discussion,competitors,kernels\n")
d = open(dataset_file, "w", encoding="utf-8")
d.write("dataset,author,size,discussions,kernels,downloads,views,vote,version\n")
# dataset: name
# author: name
# competition: yes or not
# size: how many bytes
# discussion: how many discussions if applicable. in "discussion"
# kernel: how many kernels if applicable
# vote: how many votes if applicable
# version: how many versions of dataset if applicable

counter = 0

# flag = True
for page_name in tqdm(os.listdir(Author_path)):
    ################################
    ### some kernel pages' name is "kernels_deleted_xxxxxxx".
    ### I don't know why this kind of pages comes into being.
    ### maybe this kernel is just deleted. Simple as it is.
    ### Just ignore it first.
    ################################
    # if page_name != "del=cd0be45190c25545_glove.42b.300d.html" and flag:
    #     continue
    flag = False
    if "kernels_deleted_" in page_name:
        continue

    author = page_name.split(".")[0]
    with open(os.path.join(Author_path, page_name), "r", encoding="utf-8") as f:
        html = f.read()
    page_source = etree.HTML(html)
    ###########
    # this part is for dealing with the problem
    # of: too many request.
    # we have to abondon those "too many requests" pages temprarily.
    ###########
    if page_source.xpath("/html/body/pre/text()") != []:
        continue
    ############
    _ = page_source.xpath("//div[@class='site-layout__main-content']/script[1]/text()")[0]
    p = re.compile("Kaggle\.State\.push\(\{[\s\S]*\}\)\;")
    try:
        s = p.findall(_)[0].replace("Kaggle.State.push(", "")[0:-2]
        info = json.loads(s)
    except:
        ##############################
        # this place occurs because
        # we will fail to crawl such information
        ##############################
        print("{} failed: such information cannot be parsed".format(author))
    #####################
    ## some pages will contain kernel page infomation.
    ## this is supposed to be the error of scrapy.
    ## for now, lets' just skip this kind of error.
    #####################
    if "kernel" in info:
        continue
    print(page_name)
    ##########################
    ##Some pages will still have problem, so let's just
    ## skip them.
    ##########################
    try:
        if "competitionId" in info:
            # it is a competition
            c.write("{},{},{},{},{},{}\n".format(
                info["competitionSlug"], info["organizationSlug"],
                info["databundle"]["totalSize"], info["totalDiscussions"],
                info["totalCompetitors"],get_ajax_json("&competitionId={}".format(info["competitionId"]), 200)
                )
            )
            pass
        else:
            d.write("{},{},{},{},{},{},{},{},{}\n".format(
                info["slug"],
                info["owner"]["slug"],info["data"]["totalSize"],
                info["numberOfTopics"],info["numberOfScripts"],
                info["numberOfDownloads"], info["numberOfViews"],
                info["voteCount"],info["datasetVersionTotalCount"]
                )
            )
    except:
        continue
c.close()
d.close()
print("хорошо")
# Out:
#   0%|                                                                                         | 0/1085 [00:00<?, ?it/s]
# aakashnain_xray-best-model.html
# aaron7sun_stocknews.html
# aaronschlegel_austin-animal-center-shelter-outcomes-and.html
# aaronschlegel_seattle-pet-licenses.html
# aashita_masks.html
# aashita_nyt-comments.html
#   1%|▍                                                                                | 6/1085 [00:00<00:37, 28.45it/s]
# abcsds_pokemon.html
# abecklas_fifa-world-cup.html
# abhishekmamidi_air-passengers.html
# abhishekmamidi_precipitation-data-of-pune-from-1965-to-2002.html
#   1%|▋                                                                               | 10/1085 [00:00<00:34, 30.79it/s]
# achyutanandaparida_dataset from  house sales in king county, usa.html
# adithyarganesh_english-premier-league-player-data-20172018.html
#   1%|▉                                                                               | 13/1085 [00:00<00:36, 29.56it/s]
# adityaecdrid_malware.html
# afzale_rating-vs-gross-collector.html
#   2%|█▍                                                                              | 19/1085 [00:00<00:30, 34.45it/s]
#   2%|█▊                                                                              | 25/1085 [00:00<00:28, 37.79it/s]
#   3%|██▎                                                                             | 32/1085 [00:00<00:24, 43.68it/s]
#   4%|██▊                                                                             | 38/1085 [00:00<00:22, 45.62it/s]
# ahmedelnaggar_fifa-worldcup-2018-dataset.html
# airbnb_boston.html
# akram24_wine-pca.html
# alandu20_2016-us-presidential-campaign-texts-and-polls.html
# alexattia_the-simpsons-characters-dataset.html
#   4%|███▏                                                                            | 43/1085 [00:01<00:46, 22.48it/s]
# aljarah_xAPI-Edu-Data.html
# allunia_protein-atlas-eab-predictions.html
#   4%|███▌                                                                            | 48/1085 [00:01<00:39, 26.26it/s]
# alvations_patching-pizzas.html
# alxmamaev_flowers-recognition.html
# ambarish_us-census-tracts.html
# ambarish_us-states-cartographic-boundary-shapefiles.html
#   5%|███▊                                                                            | 52/1085 [00:01<00:37, 27.64it/s]
# analystmasters_earn-your-6-figure-prize.html
# andonians_random-linear-regression.html
#  16%|████████████▎                                                                | 173/1085 [00:31<1:02:49,  4.13s/it]
# c_avito-demand-prediction.html
#  16%|████████████▋                                                                  | 174/1085 [00:34<56:50,  3.74s/it]
# c_bike-sharing-demand.html
#  16%|████████████▍                                                                | 175/1085 [00:39<1:02:08,  4.10s/it]
# c_bnp-paribas-cardif-claims-management.html
#  16%|████████████▍                                                                | 176/1085 [00:44<1:05:17,  4.31s/it]
# c_bosch-production-line-performance.html
#  16%|████████████▌                                                                | 177/1085 [00:50<1:16:38,  5.06s/it]
# c_carvana-image-masking-challenge.html
#  16%|████████████▋                                                                | 178/1085 [00:52<1:02:34,  4.14s/it]
# c_catch-me-if-you-can-intruder-detection-through-webpage-session-tracking2.html
#  16%|█████████████                                                                  | 179/1085 [00:54<50:07,  3.32s/it]
# c_caterpillar-tube-pricing.html
#  17%|█████████████                                                                  | 180/1085 [00:57<49:51,  3.31s/it]
# c_cdiscount-image-classification-challenge.html
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~\Anaconda3\lib\site-packages\urllib3\connectionpool.py in _make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     379             try:  # Python 2.7, use buffering of HTTP responses
# --> 380                 httplib_response = conn.getresponse(buffering=True)
#     381             except TypeError:  # Python 2.6 and older, Python 3
#
# TypeError: getresponse() got an unexpected keyword argument 'buffering'
#
# During handling of the above exception, another exception occurred:
#
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-2-2d3381aa6271> in <module>()
#      90             info["competitionSlug"], info["organizationSlug"],
#      91             info["databundle"]["totalSize"], info["totalDiscussions"],
# ---> 92             info["totalCompetitors"],get_ajax_json("&competitionId={}".format(info["competitionId"]), 200)
#      93             )
#      94         )
#
# <ipython-input-2-2d3381aa6271> in get_ajax_json(parameter, page_size)
#      12     while True:
#      13         r = requests.get(next_url,
# ---> 14                          auth=('user', 'pass')).json()
#      15         if len(r) == 0:
#      16             break
#
# ~\Anaconda3\lib\site-packages\requests\api.py in get(url, params, **kwargs)
#      70
#      71     kwargs.setdefault('allow_redirects', True)
# ---> 72     return request('get', url, params=params, **kwargs)
#      73
#      74
#
# ~\Anaconda3\lib\site-packages\requests\api.py in request(method, url, **kwargs)
#      56     # cases, and look like a memory leak in others.
#      57     with sessions.Session() as session:
# ---> 58         return session.request(method=method, url=url, **kwargs)
#      59
#      60
#
# ~\Anaconda3\lib\site-packages\requests\sessions.py in request(self, method, url, params, data, headers, cookies, files, auth, timeout, allow_redirects, proxies, hooks, stream, verify, cert, json)
#     506         }
#     507         send_kwargs.update(settings)
# --> 508         resp = self.send(prep, **send_kwargs)
#     509
#     510         return resp
#
# ~\Anaconda3\lib\site-packages\requests\sessions.py in send(self, request, **kwargs)
#     616
#     617         # Send the request
# --> 618         r = adapter.send(request, **kwargs)
#     619
#     620         # Total elapsed time of the request (approximately)
#
# ~\Anaconda3\lib\site-packages\requests\adapters.py in send(self, request, stream, timeout, verify, cert, proxies)
#     438                     decode_content=False,
#     439                     retries=self.max_retries,
# --> 440                     timeout=timeout
#     441                 )
#     442
#
# ~\Anaconda3\lib\site-packages\urllib3\connectionpool.py in urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     599                                                   timeout=timeout_obj,
#     600                                                   body=body, headers=headers,
# --> 601                                                   chunked=chunked)
#     602
#     603             # If we're going to release the connection in ``finally:``, then
#
# ~\Anaconda3\lib\site-packages\urllib3\connectionpool.py in _make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     381             except TypeError:  # Python 2.6 and older, Python 3
#     382                 try:
# --> 383                     httplib_response = conn.getresponse()
#     384                 except Exception as e:
#     385                     # Remove the TypeError from the exception chain in Python 3;
#
# ~\Anaconda3\lib\http\client.py in getresponse(self)
#    1329         try:
#    1330             try:
# -> 1331                 response.begin()
#    1332             except ConnectionError:
#    1333                 self.close()
#
# ~\Anaconda3\lib\http\client.py in begin(self)
#     295         # read until we get a non-100 response
#     296         while True:
# --> 297             version, status, reason = self._read_status()
#     298             if status != CONTINUE:
#     299                 break
#
# ~\Anaconda3\lib\http\client.py in _read_status(self)
#     256
#     257     def _read_status(self):
# --> 258         line = str(self.fp.readline(_MAXLINE + 1), "iso-8859-1")
#     259         if len(line) > _MAXLINE:
#     260             raise LineTooLong("status line")
#
# ~\Anaconda3\lib\socket.py in readinto(self, b)
#     584         while True:
#     585             try:
# --> 586                 return self._sock.recv_into(b)
#     587             except timeout:
#     588                 self._timeout_occurred = True
#
# ~\Anaconda3\lib\site-packages\urllib3\contrib\pyopenssl.py in recv_into(self, *args, **kwargs)
#     278     def recv_into(self, *args, **kwargs):
#     279         try:
# --> 280             return self.connection.recv_into(*args, **kwargs)
#     281         except OpenSSL.SSL.SysCallError as e:
#     282             if self.suppress_ragged_eofs and e.args == (-1, 'Unexpected EOF'):
#
# ~\Anaconda3\lib\site-packages\OpenSSL\SSL.py in recv_into(self, buffer, nbytes, flags)
#    1811             result = _lib.SSL_peek(self._ssl, buf, nbytes)
#    1812         else:
# -> 1813             result = _lib.SSL_read(self._ssl, buf, nbytes)
#    1814         self._raise_ssl_error(self._ssl, result)
#    1815
#
# KeyboardInterrupt:

# %% [markdown]
# # Parse Kernel
# * there is a problem. If a kernel uses several datasets, we cannot fit all information into measures. How to manage corresponding data in measures? Here is my solution: how many datasets they used, information of the first one dataset (what dataset it is, the type of this dataset).

# %% [markdown]
# * 2019年2月10日. First version of kernel parse. You can add more features like code and comment features.

# %%
import json, os, shutil, re
from lxml import etree

Author_path = "J:\\EECS_6414\\Data\\TEST_DATASET1\\files"
csv_file = "J:\\EECS_6414\\Data\\TEST_DATASET1\\kernel_stats.csv"
c = open(csv_file, "w", encoding="utf-8")
c.write("kernel,author,datasets,source1st,sourceType1st,versions,forks,comments,views,votes\n")
#kernel: "kernel""slug"
#author: "kernel""author""userName"
#competition: if this kernel is for competition.
#versions: "menuLinks", "title" is "Versions", "count"
#forks: "menuLinks", "title" is "Forks", "count"
#comments: "menuLinks", "title" is "Comments", "count"
#views: "kernel""viewCount"
#votes: "kernel""upvoteCount"
#about source: because a kernel may use several datasets, so here I just take the first dataset into consideration.
counter = 0

for page_name in os.listdir(Author_path):
    try:
        with open(os.path.join(Author_path, page_name + "\\webpages.html"), "r", encoding="utf-8") as f:
            html = f.read()
        page_source = etree.HTML(html)
    except:
        print("no such file: {}".format(page_name))
    ###########
    # this part is for dealing with the problem
    # of: too many request.
    # we have to abondon those "too many requests" pages temprarily.
    ###########
    if page_source.xpath("/html/body/pre/text()") != []:
        continue
    ############
    _ = page_source.xpath("//div[@class='site-layout__main-content']/script[1]/text()")[0]
    p = re.compile("Kaggle\.State\.push\(\{[\s\S]*\}\)\;")
    try:
        s = p.findall(_)[0].replace("Kaggle.State.push(", "")[0:-2]
        info = json.loads(s)
    except:
        ##############################
        # this place occurs because
        # we will fail to crawl such information
        ##############################
        print("{} failed: such information cannot be parsed".format(page_name))
    ## about versions and comments
    versions = 0
    comments = 0
    for menulink in info["menuLinks"]:
        if menulink["title"] == "Versions":
            versions = menulink["count"]
        elif menulink["title"] == "Comments":
            comments = menulink["count"]
        else:
            pass
    ####about dataset
    source = None
    sourceType = None
    tmp = info["dataSources"]
    datasets = len(tmp)
    print(page_name)
    if tmp != []:
        source = tmp[0]["slug"]
        sourceType = tmp[0]["sourceType"]
    # saving to file
    c.write("{},{},{},{},{},{},{},{},{},{}\n".format(
        info["kernel"]["slug"],
        info["kernel"]["author"]["userName"],
        datasets, source, sourceType,
        versions, info["kernel"]["forkCount"], comments,
        info["kernel"]["viewCount"], info["kernel"]["upvoteCount"]
        )
    )
c.close()
print("хорошо, total number is: {}".format(counter))
# Out:
# aagundez_pikachu-vs-bulbasaur-matchup
# aakashnain_beating-everything-with-depthwise-convolution
# aakashnain_eda-nytaxi
# aakashnain_is-it-better-than-2017
# aakashnain_kmnist-mnist-replacement failed: such information cannot be parsed
# aakashnain_kmnist-mnist-replacement
# aakashnain_let-s-check-what-the-survey-says
# aakashnain_minimal-starter
# aakashns_pytorch-basics-linear-regression-from-scratch
# aamaia_leeak
# aantonova_797-lgbm-and-bayesian-optimization
# aantonova_aggregating-all-tables-in-one-dataset
# aantonova_practical-eda-on-numerical-data
# aaraneo_nn-with-convolution-over-prev-app-and-bureau
# aashita_exploratory-data-analysis-of-comments-on-nyt
# aashita_guide-to-animated-bubble-charts-using-plotly
# aashita_training-a-bot-to-comment-on-current-affairs
# aashita_word-clouds-of-various-shapes
# aashita_xgboost-model-with-minimalistic-features
# aayush9876_you-india-you-lose
# abbysobh_classifying-client-type-using-client-names
# abdelwahedassklou_only-cat-boost-lb-0-0641-939
# abdullahcakmak_my-first-kernel-and-visualization
# abdullahsahin_bakery-market-basket-analysis
# abdullahsahin_matplotlib-tutorial-for-beginners
# abdullahsahin_numpy-tutorial-for-beginner
# abdullahsahin_step-by-step-pandas-tutorial-for-beginner
# abhilashawasthi_feature-engineering-lgb-model
# abhilashawasthi_first-lightgbm
# abhilashawasthi_unet-with-simple-resnet-blocks
# abhimanyuaryan_grocery-store-prediction
# abhimicro3_story-of-kiva
# abhishekheads_walk-through-of-different-classification-models
# abhishekmamidi_everything-you-can-do-with-seaborn
# abhishekmamidi_insights-of-kaggle-ml-and-ds-survey
# abhishekmamidi_time-series-analysis-arima-model
# abhishekmamidi_time-series-analysis-artificial-neural-networks
# abhishekmamidi_titanic-data-preprocessing-and-visualization
# abhishek_approaching-almost-any-nlp-problem-on-kaggle
# abhishek_blender
# abhishek_maybe-something-interesting-here
# abhishek_vote-me-up
# abhmul_keras-convnet-lb-0-0052-w-visualization
# abigaillarion_terrorist-attacks-in-united-states
# abigaillarion_traffic-fatalities-in-2015
# abigaillarion_ufo-reports-in-united-states
# aboliveira_analysis-of-black-friday
# abriosi_raddar-0-98-xgboost-sparse-matrix-python
# achalshah_allstate-feature-analysis-python
# adamschroeder_countvectorizer-tfidfvectorizer-predict-comments
# adamsfei_only-brand-new-features
# adelsondias_ted-talks-topic-models
# ademyttenaere_0-2748-with-rf-and-log-transformation
# ademyttenaere_build-complete-train-and-test-db
# adiljadoon_word-cloud-with-python
# aditya1702_adversarial-val-lgbm-xgb-model-lb-1-40
# adityaecdrid_initial-eda
# adityaecdrid_mnist-with-keras-for-beginners-99457
# adityaecdrid_my-first-time-series-comp-added-prophet
# adityaecdrid_simple-feature-engineering-xd
# adityapatil673_visual-analysis-of-apps-on-applestore
# adrian1acoran_starter-3-5-million-chess-games-54ee7bf0-0
# adrian1acoran_starter-averaged-perceptron-tagger-61f09bff-e
# adrian1acoran_starter-chess-black-wins-93c43b75-a
# adrian1acoran_starter-seti-data-5847883f-4
# adrian1acoran_starter-vgg-13-with-batch-2328f97b-5
# adrianmatias_futurestocks-eda-baseline-and-lightgbm
# aeshen_the-secret-to-getting-the-second-date
# afajohn_cnn-lstm-for-signal-classification-lb-0-513
# afgonczol_an-easter-egg-this-christmas
# agalea91_mislabeled-training-images
# agehsbarg_top-10-0-10943-stacking-mice-and-brutal-force
# agodwinp_stacking-house-prices-walkthrough-to-top-5
# agostontorok_soccer-world-cup-2018-winner
# no such file: agrigorev_tensorflow-starter-conv1d-embeddings-0-442-lb
# agrigorev_tensorflow-starter-conv1d-embeddings-0-442-lb
# agzamovr_a-very-extensive-exploratory-analysis-in-python
# aharless_do-not-congratulate
# aharless_exclude-same-wk-res-from-nitin-s-surpriseme2-w-nn
# aharless_fork-v8-henrique-s-model-w-randomly-higher-score
# aharless_kaggle-runnable-version-of-baris-kanber-s-lightgbm
# aharless_latest-iteration-in-this-silly-game
# aharless_logistic-of-genetic-features
# aharless_more-kaggle-runnable-version-of-baris-kanber-s-lgb
# aharless_plugging-up-the-leak-in-the-jason-saeed-result
# aharless_rgf-or-xgb-k-fold-with-log-odds-averaging
# aharless_simple-catboost-cv-lb-281
# aharless_simple-ffnn-from-dromosys-features
# aharless_simple-linear-stacking-lb-9730
# aharless_stacking-with-log-odds-and-no-intercept
# aharless_still-trying-to-do-better-than-magic-numbers
# aharless_time-deltas-for-test-based-on-test-supplement
# aharless_training-and-validation-data-pickle
# aharless_try-pranav-s-r-lgbm-in-python
# aharless_xgb-w-o-outliers-lgb-with-outliers-combined
# aharless_xgboost-cv-lb-284
# aharless_xgboost-lightgbm-and-ols
# aharless_xgboost-lightgbm-and-ols-and-nn
# aharless_xgboost-using-4th-quarter-for-validation
# ahassaine_pure-image-processing-lb-0-274
# ahmedyoussef_the-beautiful-game-analysis-of-football-events
# aikinogard_cf-starter-with-keras-0-560136
# aikinogard_random-forest-starter-with-numerical-features
# airbourne_data-dictionary
# aiswaryaramachandran_eda-and-feature-engineering
# ajalnine_titanic-keras-vs-lightgbm-vs-catboost-vs-xgboost
# ajarmstrong_separate-aggregates-for-dense-and-sparse-features
# akashram_demystify-the-random-forest
# akashsri99_deep-learning-iris-dataset-keras
# akhaisin_my-boston-house-prices
# akhileshrai003_quora-text-classification-class-imbalance-problem
# aks2411_income-prediction-86-02-accuracy
# akshay00_let-s-move-up-on-the-lb-3-703-please-upvote
# akshaysehgal_how-to-group-by-aggregate-using-py
# akshayt19nayak_getting-started-image-processing-basics
# alabsinatheer_comprehensive-exploration-and-visualization-1-1
# alabsinatheer_two-sigma-exploration-and-visualization
# alaric81li215_eda-ml-for-beginners-by-a-beginner-bonus-on-qid
# aldemuro_comparing-ml-algorithms-train-accuracy-90
# alena0604_a-little-start-for-a-big-journey
# alesgb_genetic-feature-engineering-and-evaluation
# aless80_sarimax-on-mean-visits
# alexanderkireev_deep-learning-support-9663
# alexanderkireev_experiments-with-imbalance-nn-arch-9728
# alexanderliao_exploratory-data-analysis
# alexanderliao_image-augmentation-demo-with-albumentation
# alexanderliao_u-net-bn-aug-strat-focal-loss-fixed
# alexandrebarachant_common-spatial-pattern-with-mne
# alexandrebarachant_visual-evoked-potential-vep
# alexandrnikitin_efficient-xgboost-on-sparse-matrices
# alexandruuu_final-bla-bla
# alexattia_visualizing-predicted-characters
# alexdh359_top-earning-self-described-data-scientists
# alexeyb_coursera-winning-kaggle-competitions
# alexfir_fast-test-set-reading
# alexgeiger_insightful-vast-usa-statistics-eda-efa
# alexisbcook_intro-to-unix-commands
# alexozerin_end-to-end-baseline-tf-estimator-lb-0-72
# alexpengxiao_preprocessing-model-averaging-by-xgb-lgb-1-39
# alexvonrass_how-to-get-0-5-public-auc
# alhalimi_tokenization-and-word-embedding-compatibility
# aliates_python-numpy-basics
# aliendev_example-of-pandas-dropna
# alijs1_explaining-model-s-predictions
# alijs1_quick-look-at-what-is-important-and-what-is-not
# aljaz91_ibm-s-attrition-tackling-class-imbalance-with-gbm
# allunia_eda-en-text-normalization
# allunia_feature-dynamics-looking-at-id-groups
# allunia_hidden-treasures-in-our-groceries
# allunia_how-good-does-your-chocolate-taste
# allunia_how-to-attack-a-machine-learning-model
# allunia_protein-atlas-exploration-and-baseline
# allunia_shaking-earth
# allunia_uncover-target-correlations-with-bernoulli-mixture
# aloisiodn_python-3-download-multi-proc-prog-bar-resume
# alokpratap_titanic-problem-my-first-submission
# alonalevy_cultural-diffusion-by-recipes
# alphasis_light-weight-cnn-lb-0-74
# alvations_basic-nlp-with-nltk
# alvinkaggle_housing-prices-predictions
# alvira12_class-wise-processing-lb-0-992-new-dataset
# alyosama_doc2vec-with-keras-0-77
# amadeus1996_fruits-360-transfer-learning-using-keras failed: such information cannot be parsed
# amadeus1996_fruits-360-transfer-learning-using-keras
# amansrivastava_exploration-bi-lstm-model
# ambarish_a-forty-kaggler
# ambarish_a-very-extensive-data-analysis-of-yelp
# ambarish_arxiv-data-analysis-computationandlanguagepapers
# ambarish_data-cook-eda-modelling-wordembeddings
# ambarish_different-types-of-doctorate-kagglers
# ambarish_eda-african-conflicts-with-leaflets
# ambarish_eda-and-recommendation-system-donors-choose
# ambarish_eda-fe-xgb-glm-maps-donors-choose
# ambarish_eda-us-permanent-visas-with-feature-analysis
# ambarish_eda-xgb-avito
# ambarish_eda-xgb-lgbm-home-credit-default-risk
# ambarish_extensive-analysis-know-the-developers-in-2018
# ambarish_extensive-analysis-of-beer-recipes-with-xgb-model
# ambarish_fun-in-text-mining-with-simpsons
# ambarish_fun-with-meteorites-landings-w-maps
# ambarish_grocery-eda-dirty-xgboost-arima-ets-prophet
# ambarish_kiva-data-analysis-w-naive-poverty-metric
# ambarish_ml-kaggler-types-using-kmeans-and-pca
# ambarish_omnibus-womens-and-mens-tennis-matches-analysis
# ambarish_passnyc-eda
# ambarish_recommendation-system-donors-choose
# ambarish_seinfeld-text-mining-wordembeddings-modelling
# ambarish_toxic-comments-eda-and-xgb-modelling
# ambarish_tutorial-detailed-spooky-fun-eda-and-modelling
# ambarish_tutorial-housesales-kingcounty-eda-modelling
# ambarish_very-detailed-analysis-of-cpe-ds-for-good-winner
# amberthomas_kaggle-2017-survey-results
# amelinvladislav_map-of-temperatures-and-analysis-of-global-warming
# amelthiarahel_is-data-science-for-me
# amhchiu_bag-of-ingredients-in-r
# aminejallouli_genre-classification-based-on-wiki-movies-plots
# amirrezaeian_time-series-data-analysis-using-lstm-tutorial
# amitdhakre13_simple-linear-regression-in-r
# amlanpraharaj_xgb-using-mfcc-opanichev-s-features-lb-0-811
# ammar111_youtube-trending-videos-analysis
# amneves_quick-draw-keras-cnn-model
# amorsili_fast-exploratory-data-analysis-in-r
# ampaho_foreign-policy-map-through-hrc-s-emails
# ampaho_white-collar-vs-blue-collar-crime-in-sf
# analystmasters_learnt-parameters-for-under-3-5-goals
# anand0427_classification-for-beginners
# anand0427_regression-algorithms-for-beginners
# anaskad_step-by-step-solving-titanic-problem
# anastasya_visualization-and-analysis
# andersonk_timestamps-structure
# andraszsom_predict-the-number-of-pups
# andrekos_basic-feature-benchmark-with-quantiles
# andresionek_geospatial-analysis-of-brazilian-e-commerce
# andresionek_object-oriented-santa-s-route-concorde-solver
# andresionek_understanding-the-olist-ecommerce-dataset
# andresionek_what-makes-a-kaggler-valuable
# andrewjmah_kickstarter-exploratory-data-analysis-with-r
# andrewmvd_identifying-key-cancer-predictors-with-boruta
# andrewmvd_lightgbm-in-r
# andrewrib_recovering-the-videos
# andrewrib_visualizing-imaterialist-data
# andreyg_explore-user-base-by-geo
# andreyg_top-100-kaggle-users-by-country
# anebzt_mnist-with-cnn-in-keras-detailed-explanation
# anezka_cnn-with-keras-for-humpback-whale-id
# anfro18_lower-back-pain-algorithm
# angps95_basic-classification-methods-for-titanic
# anihaldaran_my-first-machine-learning-model-on-house-prices
# aniruddhachakraborty_lasso-gbm-xgboost-top-20-0-12039-using-r
# anisayari_your-1st-data-science-project-simple-explanation
# ankasor_improved-lung-segmentation-using-watershed
# anki08_trying-feature-engineering
# ankitjha_comparing-regression-models
# ankkur13_prediction-based-on-bayes-algo-nlp-wordcloud
# ankkur13_sentiment-analysis-nlp-wordcloud-textblob
# ankur310794_eda-recommendation-sys-hack-donorchoose
# ankur310794_stackoverflow2018-drilldown-network-decisiontree
# ankur310794_unbox-the-black-box-part-1
# anlthms_convnet-0-89
# annavictoria_ml-friendly-public-datasets
# anokas_data-analysis-xgboost-starter-0-35460-lb
# anokas_data-exploration-analysis
# anokas_exploratory-data-analysis
# anokas_exploratory-data-analysis-4
# anokas_finding-boatids
# anokas_kuzushiji-mnist-cat failed: such information cannot be parsed
# anokas_kuzushiji-mnist-cat
# anokas_mercedes-eda-xgboost-starter-0-55
# anokas_outbrain-eda
# anokas_py3-image-downloader-w-progress-bar
# anokas_python3-dataset-downloader-with-progress-bar
# anokas_quick-look-at-the-data
# anokas_talkingdata-adtracking-eda
# anokas_time-travel-eda
# anokas_two-sigma-time-travel-eda
# anqitu_feature-engineer-and-model-ensemble-top-10
# anshulrai_using-fastai-in-kaggle-kernel-updated
# antgoldbloom_trueskill-for-kitefoil-rankings-by-race
# anthonypino_price-analysis-and-linear-regression
# anthonysegura_logistic-regression-from-scratch
# antmarakis_another-cleaned-data-blend-with-low-correlation
# antmarakis_another-neural-network-from-scratch
# antmarakis_cnn-baseline-model
# antonaks_mass-shooting-in-us-using-plotly
# antoninbln_nyc-taxis-trip-duration
# anttip_mercari-mlp-without-embeddings
# anttip_talkingdata-wordbatch-fm-ftrl-lb-0-9769
# anttip_wordbatch-1-3-3-fm-ftrl-lb-0-9812
# anu2analytics_how-to-raise-money-on-kickstarter
# anycode_simple-nn-baseline
# anycode_simple-nn-baseline-3
# anycode_simple-nn-baseline-4
# apapiu_exploratory-analysis-visualization
# apapiu_exploring-kobe-s-shots
# apapiu_manifold-learning-and-autoencoders
# apapiu_predictions-in-the-republican-primary
# apapiu_regularized-linear-models
# apapiu_ridge-script
# apapiu_visualize-the-time-series
# apapiu_visualizing-breeds-and-ages-by-outcome
# apollostar_bayesian-plackett-luce-rankings-model
# apollostar_which-college-is-best-for-you
# applecer_use-f1-to-select-model-lstm-based
# apryor6_detailed-cleaning-visualization
# apryor6_detailed-cleaning-visualization-python
# apryor6_detecting-frequent-opioid-prescription
# aquatic_entity-embedding-neural-net
# aquatic_flexible-lead-lag-feature-generation
# aquatic_shallow-keras-nn-with-upsampling-27-lb
# arathee2_achieving-100-accuracy
# arathee2_story-telling-with-data-science
# ariadne_simple-one-feature-linear-regression
# arindamgot_eda-prophet-mlp-neural-network-forecasting
# arindamgot_romanticreviews-moodring-directedgraph-ngram-lda
# arindamgot_star-wars-stemming-sentiment-analysis-lda-ngram
# arjanso_kernel-density-estimation-for-predicting-logerror
# arjanso_reducing-dataframe-memory-size-by-65
# arjoonn_movie-recommendations
# arjoonn_preliminary-exploration
# arjundas_donorschoose-with-content-based-filtering-approach
# arjundas_simpleanalysis-for-kiva-its-time-for-africa
# arjundas_yet-another-data-science-story
# arjunjoshua_predicting-fraud-in-financial-payment-services
# arjunsurendran_using-lstm-on-training-data
# armagansarikey_machine-learning-1-data-preprocessing
# armamut_getting-the-lungs-right
# armamut_ps-calc-15-bin-ps-calc-20-bin
# arnaldcat_a-proxy-for-sqft-and-the-interest-on-1-2-baths
# arnaldcat_unsupervised-and-supervised-neighborhood-encoding
# arnavkj95_candidate-generation-and-luna16-preprocessing
# aroraaman_quadratic-kappa-metric-explained-in-5-simple-steps
# aroragaurav_single-model-by-pranav-hitting-0-9701
# artemtprv_load-external-data
# artgor_earthquakes-fe-more-features-and-samples
# artgor_eda-and-lstm-cnn
# artgor_eda-basic-fe-and-lgb
# artgor_eda-feature-engineering-and-everything
# artgor_eda-on-basic-data-and-lgb-in-progress
# artgor_elo-eda-and-models
# artgor_exploration-of-data-step-by-step
# artgor_fork-of-eda-on-basic-data-and-lgb-in-progress
# artgor_is-this-malware-eda-fe-and-lgb-updated
# artgor_movie-review-sentiment-analysis-eda-and-models
# artgor_nn-baseline
# artgor_pytorch-whale-identifier
# artgor_russia-usa-india-and-other-countries
# artgor_seismic-data-eda-and-baseline
# artgor_simple-eda-and-model-in-pytorch
# artgor_text-modelling-in-pytorch
# artgor_text-modelling-in-pytorch-v2
# arthurlu_exploratory-tutorial-titanic
# arthurtok_0-808-with-simple-stacking
# arthurtok_2017-state-of-data-science-kaggle-survey
# arthurtok_comprehensive-python-and-d3-js-favorita-analytics
# arthurtok_decision-boundaries-visualised-via-python-plotly
# arthurtok_employee-attrition-via-ensemble-tree-based-methods
# arthurtok_feature-ranking-rfe-random-forest-linear-models
# arthurtok_fractal-dimensions-of-world-coastlines
# arthurtok_generation-unemployed-interactive-plotly-visuals
# arthurtok_ghastly-network-and-d3-js-force-directed-graphs
# arthurtok_global-religion-1945-2010-plotly-pandas-visuals
# arthurtok_interactive-intro-to-dimensionality-reduction
# arthurtok_interactive-porto-insights-a-plot-ly-tutorial
# arthurtok_introduction-to-ensembling-stacking-in-python
# arthurtok_principal-component-analysis-with-kmeans-visuals
# arthurtok_spooky-nlp-and-topic-modelling-tutorial
# arthurtok_sql-and-python-primer-bokeh-plotly
# arthurtok_super-sized-we-mcdonald-s-nutritional-metrics
# arthurtok_target-visualization-t-sne-and-doc2vec
# arthurtok_the-console-wars-ps-vs-xbox-vs-wii
# arthurtok_tsne-pca-quick-and-dirty-visuals
# arthurtok_zoomable-circle-packing-via-d3-js-in-ipython
# aruchomu_yolo-v3-object-detection-in-tensorflow
# ashishpatel26_useful-deep-learning-resources-from-github
# ashishpatel26_visual-notes-of-deep-learning-by-andrew-ng
# ashishpatel26_vowpal-wabbit-best-text-classification-fe
# ashishpatel26_whale-prediction-using-resnet-50
# ashishpatel26_zero-to-hero-chainer-tutorial-dl
# ashishpatel26_zero-to-hero-in-pytorch-ml-dl-rl
# ashkaan_lstm-baseline
# ashukr_exploration-of-220-columns-1
# asindico_a-japanese-journey
# asindico_customer-segments-with-pca
# asindico_from-exploration-to-prediction
# asindico_hr-unexpected-patterns
# asindico_icebergs-and-ships-eda-and-augmentation
# asindico_kiva-borrowers-welfare
# asindico_porto-seguro-the-essential-kickstarter
# asindico_standard-prices-vs-outliers
# asindico_text-normalization-the-essential-kickstart
# asmasem_new-york-city-taxi-trip-duration-pr-dictions
# asmitavikas_feature-engineered-0-68310
# asparago_3-basic-classifiers-and-features-correlation
# asraful70_talkingdata-added-new-features-in-lightgbm
# astandrik_journey-from-statistics-eda-to-prediction
# astrus_entity-embedding-neural-network-keras-lb-0-748
# asydorchuk_nextclick-calculation-without-hashing-trick
# asydorchuk_save-98-of-ram
# asymptote_count-extract-sea-lions
# athoul01_predicting-interview-attendence
# auroralht_restoring-the-missing-geo-data
# authman_897-sorted-columns
# auygur_step-by-step-house-price-prediction-r-2-0-77
# avehtari_bayesian-logistic-regression-with-rstanarm
# avnishnish_analysis-of-apple-s-app-store
# avrliza_black-friday-eda
# aybakana_kernel9c6dda8245
# aymenmouelhi_quora-duplicate-questions
# ayoubchebbi_youtube-8m-analytics
# badalgupta_eda-recommender-systemdeep-learningmodel-intuition
# badat0202_estimate-distribution-of-data-in-lb
# baghern_a-deep-dive-into-sklearn-pipelines
# bandiatindra_telecom-churn-prediction
# baoanh_nyc-taxi-duration-eda-by-nguyen-khac-bao-anh
# baoanh_nyc-taxi-trip-duration-by-nguyen-khac-bao-anh
# baomengjiao_embedding-with-neural-network
# batalov_making-sense-of-elo-data-eda
# bbhatt001_bakery-business-model-association-rules
# bck513_petfinder-eda
# bebonia_first-kaggle-submission-titanic-classification
# behcetsenturk_analysis-of-bakery-transactions
# beiqiwang_predictive-analysis-of-survival-rate-on-titanic
# ben519_paulo-pinto-s-log-mas-ported-to-r-lb-0-529
# benhamner_adversarial-learning-challenges-getting-started
# benhamner_example-handwritten-digits
# benhamner_exploring-hillary-clinton-s-emails
# benhamner_exploring-the-drawbridge-data
# benhamner_indicators-in-data
# benhamner_popular-datasets-over-time
# benhamner_random-forest-benchmark-r
# benjaminlott_glass-machine-learning-techniques
# benjaminlott_star-clusters-prelim-data-sorting-and-clustering
# benjibb_lstm-stock-prediction-20170507
# benwatson_new-york-new-york
# bertcarremans_data-preparation-exploration
# beymehdi_taxi-nyc-duration-bey-mehdi
# beyondbeneath_data-exploration-and-visualisations
# bguberfain_a-simple-model-using-the-market-and-news-data
# bguberfain_naive-catboost
# bguberfain_naive-keras
# bguberfain_naive-statistics
# bguberfain_naive-xgb-lb-0-317
# bguberfain_not-so-naive-way-to-convert-bson-to-files
# bguberfain_unet-with-depth
# bguberfain_vgg16-train-features
# bhaveshthaker_data-preparation-exploratory-analysis-and-modeling
# bhouwens_how-much-sugar-do-we-eat
# bhuvaneshwaran_redefining-cancer-treatment-linear-svc
# bicotsp_pmtest1
# bigironsphere_did-drought-cause-the-war-in-syria-an-r-tutorial
# bigironsphere_tutorial-maps-eda-and-models-with-nyc-census-data
# biphili_food-through-a-bakery
# biphili_seaborn-plot-to-visualize-iris-data
# biphili_university-admission-in-era-of-nano-degrees
# bisaria_titanic-lasso-ridge-implementation
# bitsofbits_naive-nnet
# bk0000_non-blending-lightgbm-model-lb-0-977
# bkamphaus_exploratory-image-analysis
# blacksix_concorde-for-5-min
# blacksix_dp-shuffle
# blacksix_flip-n-roll-fast-python-scorer
# blazeka_multi-gpu-tensorflow-convnet-0-65
# bluevalhalla_fully-convolutional-network-lb-0-193
# bluexleoxgreen_simple-feature-lightgbm-baseline
# bminixhofer_a-different-validation-technique
# bminixhofer_a-validation-framework-impact-of-the-random-seed
# bminixhofer_deterministic-neural-networks-using-pytorch
# boltmaud_who-s-the-author-of-this-kernel
# bonlime_train-test-image-mosaic
# bonovandoo_kiva-eda-extended
# bonovandoo_kiva-eda-rmarkdown
# brandenkmurray_h2o-word2vec-starter-toxic-comments
# braquino_5-fold-lstm-attention-fully-commented-0-694
# braquino_vsb-power-lstm-attention
# brassmonkey381_viewing-leak-and-machine-images
# breakfastpirate_cross-validation-methodology-using-16-golden-week
# breakfastpirate_weeks-before-after-golden-week-2016
# breemen_nyc-taxi-fare-data-exploration
# breuker_can-we-improve-by-increasing-variance
# briantc_homedepot-first-dataexploreation-k
# briwill_sql-scavenger-hunt-day-1
# brownce_admissionspredictionsregression
# bsivavenu_basics-of-text-normalization-for-beginners
# bsivavenu_house-price-calculation-methods-for-beginners
# bsivavenu_lsa-model-on-spooky-author-data
# bsivavenu_simple-data-analysis-for-beginners
# btyuhas_bayesian-optimization-with-xgboost
# buddhiniw_breast-cancer-prediction
# bugraokcu_cnn-with-keras
# burhanykiyakoglu_k-nn-logistic-regression-k-fold-cv-from-scratch
# burhanykiyakoglu_predicting-house-prices
# burhanykiyakoglu_predicting-sentiment-from-clothing-reviews
# burritodan_gstore-1-flatten
# bwboerman_r-data-table-glmnet-xgboost-with-caret
# bybell_nyc-taxi-trip-duration
# byfone_dbscan-for-cern
# byfone_riffling-for-fine-selection
# byrachonok_keras-for-search-ships-in-satellite-image
# byrachonok_pretrained-inceptionresnetv2-base-classifier
# c34klh123_explore-happiness-data
# c34klh123_iris-data-with-ggplot-shiny
# cactusplants_is-please-really-the-magic-word
# cadong_weighted-average-on-four-kernels-lb-0-495
# caicell_fun-python-eda-step-by-step
# caicell_spotify-chart-trend-seasonal-arima
# caicell_zomato-india-restaurants-eda
# calcifer_alcohol-consumption-and-average-grades
# camnugent_geospatial-feature-engineering-and-visualization
# camnugent_introduction-to-machine-learning-in-r-tutorial
# captainidiot_19260817
# colinmorris_learn-python-challenge-day-2-exercises
# colinmorris_learn-python-challenge-day-3
# colinmorris_learn-python-challenge-day-4
# colinmorris_learn-python-challenge-day-5
# colinmorris_lists
# colinmorris_loops-and-list-comprehensions
# colinmorris_strings-and-dictionaries
# colinmorris_working-with-external-libraries
# comems_nytaxis-eda-machinelearning-comems
# company_ehr-1
# couyang_3d-plotly-unsupervised-learning-and-lightgbm
# couyang_cannabis-interactive-analysis-with-nlp
# couyang_easiest-cnn-with-99-6-accuracy-using-keras-top-5
# couyang_home-credit-eda-lightgbm
# couyang_hybrid-svm-benchmark-approach-0-11180-lb-top-2
# couyang_interactive-iris-lightgbm
# couyang_star-wars-interac-drilldown-sentiment-analysis
# couyang_taxi-interac-shiny-app-unsupervised-learning
# couyang_wine-eda-dt-rf-xgb-lightgbm-svm-and-h2o
# cpmpml_a-faster-python-scoring-function
# cpmpml_gold-medals
# cpmpml_optimal-expected-submission-value
# cpmpml_optimizing-probabilities-for-best-mcc
# cpmpml_smape-weirdness
# cpmpml_spell-checker-using-word2vec
# crailtap_basic-network-analysis-tutorial
# crawford_analyzing-the-analyzers
# crawford_another-world-famous-starter-kernel-by-chris
# crawford_humble-intro-to-analysis-with-pandas-and-seaborn
# crawford_hyperparameter-search-comparison-grid-vs-random
# crawford_monkey-classifier-cnn-xception-0-90-acc
# crawford_nfl-punt-analytics-starter-kernel
# crawford_predicting-stock-prices
# crawford_python-groupby-tutorial
# crawford_python-merge-tutorial
# crawford_resize-and-save-images-as-numpy-arrays-128x128
# cttsai_ensembling-gbms-lb-203
# cttsai_forked-lgbm-w-ideas-from-kernels-and-discuss
# cttsai_smote-on-lgbm-w-ideas-from-kernels-and-discussion
# cttsai_xgb-from-ideas-from-kernels-and-discussion
# currie32_a-model-to-predict-number-of-daily-trips
# currie32_predicting-fraud-with-tensorflow
# currie32_the-importance-of-cleaning-text
# CVxTz_cnn-starter-nasnet-mobile-0-9709-lb
# CVxTz_keras-bidirectional-lstm-baseline-lb-0-069
# daavoo_grid-of-voxels-to-train-linear-model
# daavoo_tensorflow-1vs1
# dabate_black-friday-examined-eda-apriori
# dafidakk_knn-algorİthm-hw
# dalalmanish_black-friday-python
# damienpark_artificial-neural-network-using-keras
# dan195_classification-of-student-marks
# danbrice_keras-plot-history-full-report-and-grid-search
# dandres_best-public-blend-0-2204
# danielns_dsa-prevendo-diabetes-em-mulheres
# danielsobrado_weighted-ensemble-ridge-2-lgbm-lb-0-44206
# danielson_cleaning-up-market-data-errors-and-stock-splits
# danil328_ligthgbm-with-bayesian-optimization
# danilodiogo_google-play-store-eda-plotting-with-highcharts
# danilodiogo_the-astronomical-complete-eda-plasticc-dataset
# danilodiogo_top-5-countries-us-india-china-russia-brazil
# danjordan_text-analysis-classifying-listings-with-features
# danofer_different-embeddings-with-attention-fork
# danofer_genetic-variants-to-protein-features
# danofer_getting-started-with-time-series-features
# dansbecker_a-deeper-understanding-of-deep-learning
# dansbecker_advanced-uses-of-shap-values
# dansbecker_as-with
# dansbecker_basic-data-exploration
# dansbecker_building-models-from-convolutions
# dansbecker_cross-validation
# dansbecker_data-augmentation
# dansbecker_data-leakage
# dansbecker_exercise-build-your-first-machine-learning-model
# dansbecker_exercise-data-augmentation
# dansbecker_exercise-deep-learning-from-scratch
# dansbecker_exercise-dropout-and-strides-for-larger-models
# dansbecker_exercise-intro-to-deep-learning-and-computer-vis
# dansbecker_exercise-tensorflow-programming
# dansbecker_exercise-transfer-learning
# dansbecker_explore-your-data
# dansbecker_finding-your-files-in-kaggle-kernels
# dansbecker_getting-started-with-sql-and-bigquery
# dansbecker_group-by-having-count
# dansbecker_handling-missing-values
# dansbecker_how-models-work
# dansbecker_intro-to-deep-learning-and-computer-vision
# no such file: dansbecker_joining-data
# dansbecker_joining-data
# dansbecker_learn-machine-learning
# dansbecker_learning-materials-on-kaggle
# dansbecker_model-validation
# dansbecker_order-by
# dansbecker_partial-dependence-plots
# dansbecker_partial-plots
# dansbecker_permutation-importance
# dansbecker_pipelines
# dansbecker_random-forests
# dansbecker_rectified-linear-units-relu-in-deep-learning
# dansbecker_running-kaggle-kernels-with-a-gpu
# dansbecker_select-from-where
# dansbecker_selecting-and-filtering-in-pandas
# dansbecker_shap-values
# dansbecker_submitting-from-a-kernel
# dansbecker_tensorflow-programming
# dansbecker_transfer-learning
# dansbecker_underfitting-and-overfitting
# dansbecker_use-cases-for-model-insights
# dansbecker_using-categorical-data-with-one-hot-encoding
# dansbecker_what-is-log-loss
# dansbecker_xgboost
# dansbecker_your-first-machine-learning-model
# danwheble_churn-prediction-telco-customer-churn
# darbin_weighted-naive-benchmark-lb-2-081
# dariwala3_nasnet-again
# dark4user_python-programming-from-a-to-z
# darraghdog_explore-springleaf
# darraghdog_ftrl-revisited-22
# darraghdog_grouping-numerics-springleaf
# darryldias_data-exploration-dd3
# darshanadiga_time-series-data-exploration
# datacanary_xgboost-example-python
# datagray_another-set-of-ordered-columns
# datark1_malware-prediction-eda
# datark1_pugb-overall-eda-top-10-players
# datatheque_association-rules-mining-market-basket-analysis
# datauma_fifa-2019-analysis
# daveianhickey_how-to-folium-for-maps-heatmaps-time-analysis
# davero_market-data-only-baseline
# david75116_david-leroy-nyc-taxi-prediction
# davidcoxon_titanic-practice-by-davidcoxon
# davidfumo_boosted-trees-lb-0-0643707
# davidgasquez_user-data-exploration
# davids1992_speech-representation-and-data-exploration
# davidsalazarv95_fast-ai-pytorch
# davidthaler_duplicates-of-duplicates
# davidthaler_how-many-1-s-are-in-the-public-lb
# davidunknown_susan-s-adventures-in-instacart-eda
# dbarkhorn_crypto-correlation
# dbennett_test-map
# dcbeardly_successful-board-game-design
# dczerniawko_fifa19-analysis
# ddigges_exploratory-data-analysis-india-s-story
# ddigges_the-sexiest-job-of-the-21st-century
# ddmngml_trying-to-predict-used-car-value
# deadskull7_best-score-on-kaggle-96-recall
# deepaksinghrawat_introduction-to-u-net-with-simple-resnet-blocks
# deepcnn_feature-extractor-matlab2python-translated
# discdiver_deep-learning-framework-power-scores-2018
# discdiver_the-most-in-demand-skills-for-data-scientists
# divan0_multiple-linear-regression
# divrikwicky_fast-basic-lstm-with-proper-k-fold-sentimentembed
# divrikwicky_semi-magic-postprocess-0-005-lb-gain
# divrikwicky_u-net-with-simple-resnet-blocks-forked
# dixhom_data-analysis-for-beginners
# djaballah_stackoverflow-beginner-eda
# dlarionov_feature-engineering-xgboost
# dmdm02_complete-eda-voting-lightgbm
# dmdm02_feature-engineering-stacking-ensemble
# dmi3kno_allstate-eda
# dmi3kno_allstate-fingerprints-eda
# dmi3kno_redhat-hack-in-plain-english-eda
# dmilla_introduction-to-decision-trees-titanic-dataset
# dmitrypukhov_eda-and-lstm-with-generator-for-market-and-news
# dmitrypukhov_honey-bee-health-detection-with-cnn
# dmitrysaponov_interactive-chart-x-y-by-country
# doctorclo_can-you-be-a-good-football-player
# donchuk_fast-implementation-of-scoring-metric
# dongxu027_airline-delays-eda-deep-dive-lessons-learned
# dongxu027_explore-stacking-lb-0-1463
# dongxu027_mean-mix-math-geo-harmonic-lb-0-493
# dongxu027_time-series-ets-starter-lb-0-556
# donniedarko_question-similarity-using-lstm-embedding
# donyoe_exploring-youtube-trending-statistics-eda
# donyoe_santander-quick-first-view
# donyoe_taking-a-look-at-the-fifa-18-player-dataset
# dotman_data-exploration-and-visualization
# doyouevendata_kiva-exploration-by-a-kiva-lender-and-python-newb
# dredlaw_predict-donations-using-donors-past-behaviour
# dremovd_goto-pytorch-baseline
# drgilermo_3-ways-to-leave-your-employer
# drgilermo_a-tutorial-for-complete-beginners
# drgilermo_competitiveness-and-expertise-in-tennis
# drgilermo_dynamics-of-new-york-city-animation
# drn01z3_create-k-fold-splits-depths-stratified
# drobinson_tidytext-analysis-of-r-questions-on-stack-overflow
# dromosys_fork-of-fork-lightgbm-with-simple-features-cee847
# drt2290078_mask-rcnn-sample-starter-code
# dsholes_confused-start-here-link-to-final-submission
# dsoreo_testing-r
# dster_nyc-taxi-fare-starter-kernel-simple-linear-model
# dster_two-sigma-news-official-getting-started-kernel
# duttadebadri_analysing-the-olympics-for-last-120-yrs
# duttadebadri_data-insights-forecasting-donorschoose-org
# duttadebadri_detailed-nlp-project-prediction-visualization
# duttadebadri_gun-violence-in-usa-insights-forecast
# duttadebadri_most-powerful-superheroes-best-comic
# duttadebadri_overall-global-trading-statistics
# duttadebadri_stackoverflow-survey-2018-deep-insights
# duttaroy_enhanced
# duttaroy_porter-stemmer
# dvasyukova_a-linear-model-on-apps-and-labels
# dvasyukova_predict-hotel-type-with-pandas
# dvasyukova_scripty-mcscriptface-the-lazy-kaggler
# dvasyukova_the-biggest-impacts-on-name-popularity
# dvasyukova_the-locations-puzzle
# dvasyukova_user-portraits
# dwarkanath_titanic-neural-networks
# eashish_bidirectional-gru-with-convolution
# eashish_wordbatch-with-fm-ftrl
# ebberiginal_tgs-salt-keras-unet-depth-data-augm-strat
# ebertolo_machine-learning-101-lab00
# eddfung_xgboost-for-prediction
# edouardthomas_beat-the-bookmakers-with-machine-learning-tennis
# eduardomineo_u-net-lung-segmentation-montgomery-shenzhen
# eeronan_catboost-vs-xgboost-5x-faster
# efeergun96_analysis-of-the-global-happiness-scores
# egmaldonado10_sql-scavenger-hunt-day-3
# eikedehling_feature-engineering
# eikedehling_stack-of-svm-elasticnet-xgboost-rf-0-55
# eikedehling_trying-out-stacking-approaches
# eikedehling_tune-and-compare-xgb-lightgbm-rf-with-hyperopt
# ekami66_0-92837-on-private-lb-solution-with-keras
# ekami66_detailed-exploratory-data-analysis-with-python
# elenacuoco_simple-grasp-with-sklearn
# elenapetrova_joyful-analysis-of-death-causes
# elenapetrova_time-series-analysis-and-forecasts-with-prophet
# eliekawerk_glass-type-classification-with-machine-learning
# eliotbarr_dimensionality-reduction-explained
# eliotbarr_stacking-test-sklearn-xgboost-catboost-lightgbm
# eliotbarr_text-classification-using-neural-networks
# eliotbarr_text-mining-with-sklearn-keras-mlp-lstm-cnn
# emilaye_nyc-ttd-ed
# emmarex_plant-disease-detection-using-keras
# endintears_real-machine-learning
# endlesslethe_siwei-digit-recognizer-top20
# enerrio_scary-nlp-with-spacy-and-keras
# enespolat_gender-recognition-by-voice-using-lr
# enrique1500_predict-oeis-with-markov-chains
# enrique1500_rental-listing-ny-map
# eorleli_heart-dataset-with-explanations
# eoveson_convai-datasets-baseline-models
# eraaz1_a-comprehensive-guide-to-titanic-machine-learning
# eray1yildiz_using-lstms-with-attention-for-emotion-recognition
# erichamers_is-the-real-estate-market-going-to-crash-again
# erick5_predicting-house-prices-with-machine-learning
# erikbruin_airbnb-the-amsterdam-story-with-interactive-maps
# erikbruin_google-analytics-eda-lightgbm-screenshots
# erikbruin_gun-violence-in-the-us-interactive-maps-and-eda
# erikbruin_house-prices-lasso-xgboost-and-a-detailed-eda
# erikbruin_movie-recommendation-systems-based-on-tmdb
# erikbruin_petfinder-my-detailed-eda-and-xgboost-baseline
# erikbruin_r-vs-python-and-kmodes-clustering-2018-survey
# erikbruin_recommendations-to-passnyc-1st-place-solution
# erikbruin_text-mining-the-clinton-and-trump-election-tweets
# erikbruin_titanic-2nd-degree-families-and-majority-voting
# erykwalczak_initial-loan-book-analysis
# esmaeilfarhang_interactive-visualization-with-python-plot-ly
# etakla_exploring-the-dataset-bivariate-analysis
# etatbak_rnn-vs-lstm-on-bitcoin-datas
# etheleon_exploratory-analysis-image-stats
# eugen1701_predicting-sentiment-and-helpfulness
# evaart_nlp-with-ml
# evanmiller_learning-sql-the-dplyr-way
# evanmiller_python-for-padawans
# ezietsman_airbus-eda
# fabiendaniel_categorizing-actors-hands-on-plotly
# fabiendaniel_customer-segmentation
# fabiendaniel_detecting-malwares-with-lgbm
# fabiendaniel_elo-world
# fabiendaniel_film-recommendation-engine
# fabiendaniel_lgbm-starter
# fabiendaniel_my-2cents-to-2sigma
# fabiendaniel_predicting-flight-delays-tutorial
# fabiendaniel_recruit-restaurant-eda
# fabiendaniel_selecting-features
# fabienvs_grupo-bimbo-data-analysis
# fahd09_eda-of-crime-in-chicago-2005-2016
# faizalabdkadir_recruit-visual-eda-itadakimasu
# famazon_adversarial-validation-set
# fanzzz_understand-variables-in-chinese
# farazrahman_are-we-producing-enough-food-simple-time-series
# farazrahman_clustering-the-donors-with-rfm-analysis
# farazrahman_kiva-loans-crisp-basic-analysis
# farazrahman_lending-club-check-before-you-cheque
# farazrahman_passnyc-understanding-the-data
# farazrahman_predicting-star-galaxy-quasar-with-svm
# farazrahman_stackoverflow-and-the-challenge-of-inclusiveness
# farazrahman_telco-customer-churn-logisticregression
# farazrahman_woggler-the-women-kaggler
# favellore_kernel97cb5c29d9
# fayzur_detecting-malwares-with-ftrl-proximal
# fchollet_keras-starter-code
# fcostartistican_don-t-mess-with-my-mothjer
# fffjay_titanic-survivor-predict
# ffisegydd_sklearn-multicollinearity-class
# fiancheto_petfinder-simple-lgbm-baseline-lb-0-399
# filibertogh_starter-graduate-admissions-1a5b7963-3
# filthyilliterate_transitioning-from-academia-to-industry
# fiorenza2_journey-to-the-top-10
# fiqhrimuliandaputra_starter-malaria-cell-images-dataset-e0567bed-9
# firstprayer_understand-loyalty-score-w-r-t-hist-vs-new
# fizzbuzz_beginner-s-guide-to-audio-data
# fizzbuzz_beginner-s-guide-to-capsule-networks
# fizzbuzz_bi-lstm-conv-layer-lb-score-0-9840
# fizzbuzz_rank-averaging-on-preprocessed-data
# fkosmowski_matching-kiva-s-borrowers-with-dhs-clusters
# flaport_tensorflow-cnn-lb-0-98929
# flennerhag_ml-ensemble-scikit-learn-style-ensemble-learning
# fmarazzi_baseline-keras-cnn-roc-fast-10min-0-925-lb
# fmuetsch_keras-nn-with-rec-layers-sentiment-etc-2
# forzzeeteam_montecarlo-model-selection
# fppkaggle_making-tifs-look-normal-using-spectral-fork
# francksylla_titanic-machine-learning-from-disaster
# frankherfert_local-validation-with-detailed-product-comparison
# frankherfert_region-and-city-details-with-lat-lon-and-clusters
# frednavruzov_auto-feature-generation-featuretools-example
# frednavruzov_baseline-to-start-with-keras-lb-0-55
# frednavruzov_dumb-and-the-dumber-baselines-plb-0-3276826
# frednavruzov_instacart-exploratory-data-analysis
# frednavruzov_nyc-taxi-eda-feature-engineering
# freel21_moreno-antonin-first-attempt
# freespirit08_time-series-for-beginners-with-arima
# frkngnr_donorschoose-org-data-analysis-project
# frtgnn_elo-eda-lgbm
# fruitvul_smartmeter-roll-out-energy-consumption-in-nl
# fujisan_use-keras-pre-trained-vgg16-acc-98
# ...
# thebrownviking20_passnyc-eda-and-unsupervised-learning
# thebrownviking20_who-said-this-line-eda-classification-keras-ann
# thelordofmke_starter-fifa-19-complete-player-a615a09e-0
# themissingsock_exploring-renthop-data
# themixedfermions_mask-hotmaps
# theoviel_dealing-with-class-imbalance-with-smote
# theoviel_fast-fourier-transform-denoising
# theoviel_greedy-reindeer-starter-code
# theoviel_how-far-can-you-go-using-only-train-test-files
# theoviel_improve-your-score-with-some-text-preprocessing
# theoviel_improve-your-score-with-text-preprocessing-v2
# theoviel_load-the-totality-of-the-data
# theoviel_should-you-clean-your-data
# theoviel_starter-code-eda-and-lgbm-baseline
# theoviel_using-word-embeddings-for-data-augmentation
# theoviel_winner-winner-turkey-dinner-lb-0-990
# thepathofd_a-first-kaggle-part-1-forecasting-store-47
# therealpythonman_get-350k-additional-hpa-images
# thevinaymittal_credit-card-fraud-detection
# thexyzt_keeping-it-simple-by-xyzt
# thexyzt_xyzt-s-visualizations-and-various-tsp-solvers
# thibalbo_wow-dataset-exploratory-analysis
# thie1e_exploratory-analysis-rossmann
# thijskranenburg_descriptive-statistics-group-tdrg
# thomascrough_exploring-craft-brewery-data
# thomasjpfan_q-a-with-only-pictures
# thousandvoices_logistic-regression-with-words-and-char-n-grams
# threeplusone_sea-lion-coordinates
# thuongdinh_ensemble-with-best-weights-finding
# thykhuely_mercari-interactive-eda-topic-modelling
# thykhuely_recruit-time-series-interactive-eda
# tibhar940_chocolate-bar-ratings-python-eda-dataviz
# tilii7_boruta-feature-elimination
# tilii7_cross-validation-weighted-linear-blending-errors
# tilii7_dimensionality-reduction-pca-tsne
# tilii7_feature-discretization-less-is-better
# tilii7_features-we-don-t-need-no-stinking-features
# tilii7_new-features-xgb-upsampling-bayesopt
# tilii7_olivier-lightgbm-parameters-by-bayesian-opt
# tilii7_tuned-logreg-oof-files
# tilii7_very-hard-way-to-get-0-290-on-the-lb
# timolee_a-home-for-pandas-and-sklearn-beginner-how-tos
# timolee_audio-data-conversion-to-images-eda
# timolee_fastai-kaggle-starter-kit-lb-0-33
# timolee_feeling-hungry-a-beginner-s-guide-to-arima-models
# timolee_finding-trees-through-the-forest-a-rf-dissection
# timosdk_exploring-motivations-for-kiva-loans
# timothycwillard_vsb-power-line-faults-eda-feature-engineering
# timucinanuslu_data-crunchers
# tini9911_imbalance-in-data
# titericz_black-white-cnn-lb-0-782
# titericz_giba-countvectorizer-d-lb-1-43
# titericz_giba-darragh-ftrl-rerevisited
# titericz_winner-model-giba-single-xgb-lb0-5178
# tj2552_similarity-techniques-nlp
# tkm2261_my-15th-solution-features-mainly-using-bigquery
# tks0123456789_word-phrase-importance
# tobikaggle_nn-through-keras-copied-mod-shuffle
# tonyder_helloworld
# tonyliu_initial-look-race-vs-class-heatmap
# tonyliu_swordsman-and-their-swords-a-tree-model
# tonyliu_the-battle-of-smart-phones
# tonyyy_how-to-get-atomic-coordinates
# toregil_mystery-planet-99-8-cnn
# toregil_welcome-to-deep-learning-cnn-99
# torrinos_exploration-and-plotting
# toshif_ieee-image-manipulation-kernel
# toshik_image-size-and-rate-of-new-whale
# tour1st_magic-feature-v2-0-045-gain
# tpgdatascience_achieve-100-credit-card-fraud-detection
# tqchen_understanding-xgboost-model-on-otto-data
# treina_feature-extractor-matlab2python-translated
# triskelion_kappa-intuition
# triskelion_mapping-with-sum-row
# triskelion_normalized-kaggle-distance
# triskelion_testing-python-3
# truocpham_feature-engineering-and-lightgbm-starter
# tsilveira_salt-identification-features
# tsilveira_time-frequency-analysis-with-stft
# tunguz_annoying-ab-shreck-and-bluetooth
# tunguz_bi-gru-cnn-poolings-gpu-kernel-version
# tunguz_bow-meta-text-and-dense-features-lb-0-2241
# tunguz_cnn-glove300-3-oof-4-epochs
# tunguz_eda-with-python-datatable
# tunguz_elo-adversarial-validation
# tunguz_elo-with-h2o-automl
# tunguz_eloda-with-feature-engineering-and-stacking
# tunguz_how-toxic-are-hillary-and-trump-tweets
# tunguz_just-some-simple-eda
# tunguz_lb-0-286-with-submission-file
# tunguz_lgbm-starter-2
# tunguz_logistic-regression-with-words-and-char-n-grams
# tunguz_lr-with-words-and-char-n-grams-baseline
# tunguz_lstm-gru-why-not-both
# tunguz_malware-feature-engineering-full-train-and-test
# tunguz_mitsuru-features-only-train-and-test
# tunguz_more-effective-ridge-lgbm-script-lb-0-44341-2
# tunguz_more-effective-ridge-lgbm-script-lb-0-44823
# tunguz_ms-malware-adversarial-validation
# tunguz_naive-subsampled-xgb-starter
# tunguz_quora-adversarial-validation
# tunguz_surprise-me-2
# tunguz_wordbatch-ftrl-fm-lgb-lbl-0-42506
# tunguz_xgboost-one-step-ahead-lb-0-519
# tunguz_xgboost-starter
# tunguz_yaeda-yet-another-eda
# tutanay_my-first-kernell
# twhitehurst3_cancer-detect-keras
# uds5501_chicago-crime-mapping
# uds5501_cnn-segmentation-resnet-depth-5
# ug2409_using-description-as-the-only-feature-72-cv
# uiiurz1_how-does-the-image-scale-affect-dice
# ultragamza_compute-cost-accelerator-by-tensorflow-gpu
# umbertogriffo_deep-learning
# umeshnarayanappa_explore-911-data
# umeshnarayanappa_explore-global-terrorism-using-highcharter
# umeshnarayanappa_explore-nyc-uber-trips
# umeshnarayanappa_explore-philly-crime-data
# umeshnarayanappa_explore-video-games-sales
# umeshnarayanappa_exploring-starbucks-stores
# umeshnarayanappa_exploring-the-data
# umeshnarayanappa_exploring-top-500-indian-cities
# umeshnarayanappa_forecasting-chicago-crimes-2017-2020
# umeshnarayanappa_kiva-detailed-analysis-using-highcharter-leaflet
# umeshnarayanappa_map-extinct-endangered-languages-matplotlib
# umeshnarayanappa_quickstart-guide-shapefiles-and-r-tmap
# umeshnarayanappa_stack-overflow-developer-survey-visual-story
# umeshnarayanappa_the-world-needs-kaggle
# umutto_preliminary-data-analysis-using-word2vec
# unsunnedsnow_honey-bee-health-classifier-simplified
# usengecoder_introduction-to-data-science
# usman786_learn-python-for-data-science
# vaibhavsagar_titanic-by-a-beginner
# vaishaligarg_analysing-ipl-data
# valentinw_simple-data-exploration-and-visualization
# valkling_how-to-teach-an-ai-to-dance
# valkling_mercari-rnn-2ridge-models-with-notes-0-42755
# vamsikrishna_basic-eda-and-xgboost
# vamsikrishna_exploratory-data-analysis-of-ipl-data
# vamsikrishna_happiness-index-and-terrorism
# vamsikrishna_indian-climate-dynamics
# vannak_nn-starter-no-period-image-title-desc
# vanshjatana_basic-analysis
# vanshjatana_diffrent-embedding-please-upvote
# vanshjatana_malware-predictions
# varunsukumar27_olympics-in-depth-eda
# vbookshelf_cnn-how-to-use-160-000-images-without-crashing
# vbookshelf_skin-lesion-analyzer-tensorflow-js-web-app
# vchoubey_random-forest-mean-encoding-for-app-channel
# veereshelango_celebrity-death-analysis
# venky73_predicting-student-percentage
# vfdev5_data-exploration-1
# vfdev5_data-visualization
# vfdev5_data-visualization-and-analysis
# vfdev5_pil-vs-opencv
# vfdev5_train-dataset-visualization
# vfdev5_type-1-clustering
# vfdev5_who-are-they-data-scientists
# vghorakavi_two-sigma-exploratory-kernel
# vhrique_simple-house-price-prediction-stacking
# vicensgaitan_image-registration-the-r-way
# vicensgaitan_salt-jigsaw-puzzle
# victorambonati_unsupervised-anomaly-detection
# victorgrobberio_visualizing-smelling-and-feeling-business-data
# victorhz_cnn-with-20-classes-trained-validation-set
# vijaybj_basic-u-net-using-tensorflow
# vijaybj_yolo-for-detection-of-bounding-boxes-tensorflow
# vikramb_mobile-price-prediction
# vin1234_best-titanic-survival-prediction-for-beginners
# vincentlugat_breast-cancer-analysis-and-prediction
# vincentlugat_ibm-attrition-analysis-and-prediction
# vincentlugat_lightgbm-plotly
# vincentlugat_titanic-data-analysis-lgbm-0-82296
# vincentlugat_titanic-data-analysis-rf-prediction-0-81818
# vincentlugat_votingclassifier-f1-score-0-88-data-viz
# vinothan_eda-for-titanic-data-chanllege
# vinothan_prefect-eda-for-house-credit-default-risk
# vinothan_titanic-model-with-90-accuracy
# virtonos_housing-prices-forecasts
# vishalbajaj2000_basic-tabular-test-train-compare
# vishalyo990_prediction-of-quality-of-wine
# visoft_export-pixel-wise-mask
# viveksrinivasan_eda-ensemble-model-top-10-percentile
# viveksrinivasan_eda-focus-on-missing-values-and-simple-xgb
# viveksrinivasan_visualizing-two-sigma-connect-dataset
# viveksrinivasan_zillow-eda-on-missing-values-multicollinearity
# vjgupta_reach-top-10-with-simple-model-on-housing-prices
# vksbhandary_big-data-analysis-analyzing-hacker-news-stories
# vkutelc_fifa-19-kernel
# vlasoff_beginner-s-guide-nn-with-multichannel-input
# voglinio_external-h-e-data-with-mask-annotations
# voglinio_from-masks-to-bounding-boxes
# vpaslay_is-your-small-gini-significant
# vprokopev_mean-likelihood-encodings-a-comprehensive-study
# vrtjso_lgbm-one-step-ahead
# vrtjso_mercari-eda-more-info-than-you-can-imagine
# vsesham_cut-the-time
# vsmolyakov_keras-cnn-with-fasttext-embeddings
# vukglisovic_classification-combining-lda-and-word2vec
# vykhand_exploring-products
# waitingli_combining-your-model-with-a-model-without-outlier
# waltmay_u-net-with-simple-resnet-blocks-and-mosaic
# wangsg_ensemble-stacking-lb-0-6436
# warpri81_diving-for-features
# wcukierski_concorde-solver
# weiji14_yet-another-keras-u-net-data-augmentation
# wendykan_average-normalized-happiness-demo
# wendykan_computing-weighted-reindeer-weariness
# wendykan_don-t-know-what-i-want-to-do-yet
# wendykan_starter-explore-youtube8m-sample-data
# wenjiebai_if-you-run-on-entire-dataset-lb-0-9798
# wenxuanchen_sklearn-random-forest
# wesamelshamy_effect-of-price-on-deal-probability
# wesamelshamy_high-correlation-feature-image-classification-conf
# wesamelshamy_image-feature-extraction-and-matching-for-newbies
# wesamelshamy_trackml-problem-explanation-and-data-exploration
# whitebird_mercari-price-3rd-0-3905-cv-at-pb-in-3300-s
# wikaiqi_titaniclearningqi
# willcanniford_chocolate-bar-ratings-extensive-eda
# willcanniford_predicting-lower-back-pain-using-caret-in-r
# willieliao_et1-ridge3-med-adj
# willieliao_making-the-master-tier-top-10-version
# willkoehrsen_a-complete-introduction-and-walkthrough
# willkoehrsen_a-walkthrough-and-a-challenge
# willkoehrsen_automated-feature-engineering-basics
# willkoehrsen_automated-model-tuning
# willkoehrsen_featuretools-for-good
# willkoehrsen_intro-to-model-tuning-grid-and-random-search
# willkoehrsen_introduction-to-feature-selection failed: such information cannot be parsed
# willkoehrsen_introduction-to-feature-selection
# willkoehrsen_introduction-to-manual-feature-engineering
# willkoehrsen_introduction-to-manual-feature-engineering-p2
# willkoehrsen_model-tuning-results-random-vs-bayesian-opt
# willkoehrsen_start-here-a-gentle-introduction
# willkoehrsen_tuning-automated-feature-engineering-exploratory
# windsurfer_baseline-u-net-on-pytorch
# wittmaan_exploratory-analysis-on-county-time-series
# wittmaan_exploring-the-data
# wizarddata_multiple-lgbm-tabular-data-only
# wkevin_house-prices
# wolfgangb33r_avito-prediction-xgboost-simple
# wolfgangb33r_simple-talkingdata-prediction-xgboost
# wordroid_inceptionresnetv2-resize256-f1loss-lb0-419
# wrosinski_clean-workflow-in-keras
# wrosinski_featureaggregator-end-to-end-feature-engineering
# wrosinski_pytorch-educational-baseline
# wrosinski_shap-feature-importance-with-feature-engineering
# wti200_exploratory-analysis-nyc-taxi-trip
# wti200_xgb-with-one-hot-encoding-r
# wti200_xgboost-with-one-hot-encoding-r
# wvadim_keras-tf-lb-0-18
# xavierbourretsicotte_light-gbm-wip
# xavierbourretsicotte_localizing-utc-time-eda-and-walkthrough
# xaviertrs_nyc-taxi-trip-duration-by-xavier-terrasson
# xhlulu_exploration-and-preprocessing-for-keras-224x224
# xinyueniu_practise
# xirudieyi_house-prices
# xsakix_pytorch-bilstm-meta-v2
# xsakix_torch-ensemble
# xvivancos_analyzing-a-pok-mon-data-set-my-first-kernel
# xvivancos_analyzing-star-wars-movie-scripts
# xvivancos_analyzing-the-lord-of-the-rings-data
# xvivancos_clustering-wines-with-k-means
# xvivancos_discovering-barcelona
# xvivancos_discovering-barcelona-part-ii
# xvivancos_eda-the-cure-discography
# xvivancos_eda-tweets-during-cavaliers-vs-warriors
# xvivancos_kobe-bryant-shot-selection
# xvivancos_market-basket-analysis
# yadavsarthak_you-got-this-feature-engineering-and-lasso
# yangnanhai_keras-around-0-9633
# yassineghouzam_don-t-know-why-employees-leave-read-this
# yassineghouzam_introduction-to-cnn-keras-0-997-top-6
# yassineghouzam_titanic-top-4-with-ensemble-modeling
# ydalat_titanic-a-step-by-step-intro-to-machine-learning
# yekenot_2dcnn-textclassifier
# yekenot_baseline-with-decomposition-components
# yekenot_catboostarter
# yekenot_explore-ts-with-lstm
# yekenot_pooled-gru-fasttext
# yekenot_simple-stacker-lb-0-284
# yekenot_textcnn-2d-convolution
# yekenot_toxic-regression
# yemregundogmus_political-opinion-with-machine-learning
# ygtcrt_how-to-deal-with-features-in-renthop-data
# yhyu13_hr-explore-predict-rf-who-to-quit-the-job
# yibochen_xgboost-in-r-2-27217
# yildirimarda_decision-tree-visualization-submission
# yitzhakr_moscow-houses-prices-analysis
# ykhorramz_lda-and-t-sne-interactive-visualization
# ymaricar_hackerrank-survey-focus-on-girl-code-power
# ymcdull_ridge-lb-0-0100659
# ymlai87416_web-traffic-time-series-forecast-with-4-model
# ynouri_random-forest-k-fold-cross-validation
# yohanb_categorical-features-encoding-xgb-0-554
# yonilev_the-most-predictable-league
# youhanlee_3250feats-532-feats-using-shap-lb-0-436
# youhanlee_eda-lgbm-for-starter-lb-1-6878
# youhanlee_eda-stratifiedshufflesplit-xgboost-for-starter
# youhanlee_extensive-eda-for-application-and-bureau-data
# youhanlee_features-which-distinguish-train-from-test
# youhanlee_hello-elo-ensemble-will-help-you
# youhanlee_my-eda-i-want-to-see-all
# youhanlee_simple-quant-features-using-python
# youhanlee_stratified-sampling-for-regression-lb-1-4627
# youhanlee_unet-resnetblock-hypercolumn-deep-supervision-fold
# no such file: youhanlee_which-encoding-is-good-for-time-validation-1-4417
# youhanlee_which-encoding-is-good-for-time-validation-1-4417
# youhanlee_who-is-the-kaggler-let-s-see-them-with-survey
# youhanlee_would-it-be-possible-to-predict-success-of-app
# ysidhu_two-sigma-portfolio-returns-eda
# yuabka_interpreting-the-data-for-my-university-transfer
# yufengg_fashion-mnist
# yukikubo123_how-to-calculate-the-score
# yuliagm_be-careful-about-ips-as-a-signal
# yuliagm_talkingdata-eda-plus-time-patterns
# yuqingxue_data-visualization-and-analysis-with-tidyverse
# yuriicojocari_eda-analysis
# yushas_imageprocessingtips
# yuval6967_3rd-place-cnn
# yuval6967_7th-place-clustering-extending-ml-merging-0-75
# yvestrang_nyc-taxi-trip-duration-by-trang-yves
# yyll008_gru-25-12-12-with-keras-512-64-relu-sgdr-lb0-432
# zahaviguy_what-are-lung-opacities
# zahedi_first-xgb
# zavodrobotov_best-public-notebook-kernel
# zeemeen_i-have-a-clue-what-i-am-doing-noise-patterns
# zehaiwang_stackoverflow-preliminary-eda
# zeroblue_mad-scripts-battle-z
# zeroblue_xgboost-with-optimized-offsets
# zeus75_xgboost-features-scoring-with-ligthgbm-model
# zfturbo_greedy-children-baseline-v2-0-7455
# zfturbo_happiness-vs-gift-popularity-v2-0-89
# zfturbo_infinite-probabilistic-improver-0-931
# zfturbo_leakage-solution
# zfturbo_mass-hashes
# zfturbo_santander-battle
# zfturbo_scoring-function
# zfturbo_seizure-boost-0-6-lb
# zhangjuefei_death-metal-s-development
# zhangjuefei_explore-and-classify-birds-by-their-bones
# zhav1k_make-it-beautiful-with-seaborn-xgb-model
# zhiboyang_feature-selection-and-prediction
# zhy450324080_death-prediction-battle-analysis
# zikazika_easy-deep-learning-using-keras
# zikazika_ensamble-methods-on-regression
# zikazika_lightgbm-2sigma
# zikazika_lightgbm-automated-feature-engineering-easy
# zikazika_memory-problems
# zikazika_natural-language-processing-theory-and-practice
# zikazika_predicting-sickness-with-weather-data
# zikazika_theory-and-practice-of-image-processing-cnn
# zikazika_tutorial-on-topic-modelling-lda-nlp
# zikazika_understandable-titanic-challenge
# zikazika_useful-new-features-and-a-optimised-model
# zikazika_using-rnn-and-arima-to-predict-bitcoin-price
# ziliwang_baseline-pytorch-bilstm
# zlatankr_titanic-random-forest-82-78
# zoujie_analyze-power-line-signals-like-a-physicist
# zoulahlou_new-york-taxi-trip-duration-zouhair-lahlou
# zoupet_exploratory-data-analysis
# zoupet_neural-network-model-for-house-prices-tensorflow
# zoupet_predictive-analysis-with-different-approaches
# zoupet_xgboost-ridge-lasso
# zusmani_election-data-wrangling
# zusmani_lgb-esemble-xgb-be-in-top-100-with-lb-0-285
# zxspectrum_ensemble-public-submissions-top-9
# zygmunt_predict-sales-with-pandas-py
# хорошо, total number is: 0

# %% [markdown]
# # Model Fitting Parts

# %% [markdown]
# * join the tables

# %%
import pandas as pd
import os
os.chdir("J:\\EECS_6414\\Data\\TEST_DATASET1")
author = pd.read_csv("stats/author_stats.csv", encoding="utf-8")
author.rename(index=str, 
              columns={"competition": "author_competitions", 
                                  "kernel": "author_kernels", 
                                  "discussion": "author_discussions", 
                                  "follower": "author_followers",
                                  "following": "author_following"}, 
              inplace=True)

competition = pd.read_csv("stats/competition_stats.csv",encoding ='latin1') ## very strange
competition.rename(index=str, 
             columns={"discussion": "competition_discussion", 
                      "kernels": "competition_kernels"}, 
             inplace= True)

dataset = pd.read_csv("stats/dataset_stats.csv",encoding ='utf-8')
dataset.rename(index=str, 
              columns={"author": "dataset_author", 
                                  "discussions": "dataset_discussions", 
                                  "kernels": "dataset_kernels", 
                                "downloads": "dataset_downloads", 
                               "views": "dataset_views", 
                               "vote": "dataset_votes", 
                                  "version": "dataset_versions"}, 
              inplace=True)

kernel = pd.read_csv("stats/kernel_stats.csv", encoding="utf-8")
kernel.rename(index=str, 
             columns={"datasets": "kernel_datasets", 
                      "versions": "kernel_versions"}, 
             inplace= True)

# kernel_competition_author.csv generating: 
kernel_competition = kernel[kernel["sourceType1st"]=="competition"]
kernel_competition = kernel_competition.drop(['sourceType1st'], axis=1)
kernel_competition.rename(index=str, columns={"source1st": "competition"}, inplace=True)

a = pd.merge(kernel_competition, competition, on='competition')
b = pd.merge(a, author, on='author')
b.to_csv("kernel_competition_author.csv", index=None)

# kernel_dataset_author.csv generating: 
kernel_dataset = kernel[kernel["sourceType1st"]=="dataset"]
kernel_dataset = kernel_dataset.drop(['sourceType1st'], axis=1)
kernel_dataset.rename(index=str, columns={"source1st": "dataset"}, inplace=True)

a = pd.merge(kernel_dataset, dataset, on='dataset')
b = pd.merge(a, author, on='author')
b.to_csv("kernel_dataset_author.csv", index=None)
