# %% [markdown]
# # Setting working directory

# %% [markdown]
# ## Load the Google drive

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
## 查看内存容量
# !free -m
# Out:
#               total        used        free      shared  buff/cache   available
# Mem:          13021         528       10538           0        1953       12224
# Swap:             0           0           0

# %% [markdown]
# ## Change the workding dir to:
#
# `'/content/drive/My Drive/Colab Notebooks/MachineLearningPractice/FinanceRiskControl'`

# %%
import os
os.chdir('/content/drive/My Drive/Colab Notebooks/MachineLearningPractice/XiamenIntlBank')
# !ls
# Out:
# 2.0-EDA-1-ForQuarter1_aka_testData.ipynb	  originalDataset
# 2.0-EDA-1-forQuarter3.ipynb			  preprocessedData
# 3.0-FE-Original.ipynb				  submissionResults
# 3.1-FE-KeepTheFeaturesAsTheyOriginallyWere.ipynb  wasted

# %%
# import os
# os.getcwd()
# Out:
# '/mnt/h/Deleteable/XiamenBank'

# %%
# os.makedirs("originalDataset")
# os.makedirs("preprocessedData")
# os.makedirs("submissionResults")

# %% [markdown]
# ## Go to this place for original dataset:
#
# `'/content/drive/My Drive/Colab Notebooks/MachineLearningPractice/FinanceRiskControl/originalDataset'`

# %%
# ## unzip the data if necessary
# !unzip originalDataset/给选手数据.zip -d originalDataset

# %% [markdown]
# # Importing libraries

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import datetime
from tqdm import tqdm
from sklearn.preprocessing import LabelEncoder
from sklearn.feature_selection import SelectKBest
from sklearn.feature_selection import chi2
from sklearn.preprocessing import MinMaxScaler
import xgboost as xgb
import lightgbm as lgb
# from catboost import CatBoostRegressor
import warnings
from sklearn.model_selection import StratifiedKFold, KFold
from sklearn.metrics import accuracy_score, f1_score, roc_auc_score, log_loss
# import tqdm
warnings.filterwarnings('ignore')

# %% [markdown]
# # EDA targets

# %% [markdown]
# * Month type data: `aum, cunkuan, behavior`
# * Quarter type data: `big_event, cust_avli, cust_info`

# %% [markdown]
# 看label的分布，多少个类别，每一个类别各占多少。
#
# 对object的和numerical的进行区分。
#
# 。。。。想到再说

# %% [markdown]
# # Starting EDA

# %% [markdown]
# ## merge the table for a quater
#
# In this example, for quarter 3 (month 7, 8, 9)

# %%
## shall we merge the quarter data first?

# %%
def changeColName(df_origin, df_name):
    '''
    df_origin is data frame
    df_name is string, the name of the dataframe
    '''
    df = df_origin.copy()
    cols = df.columns
    newCols = []
    for col in cols:
        if col == "cust_no":
            newCol = col
        else:
            newCol = "{}_{}".format(df_name, col)
        newCols.append(newCol)
    df.columns = newCols
    return df

# %%
aum_m7 = pd.read_csv('originalDataset/x_train/aum_train/aum_m10.csv')
aum_m8 = pd.read_csv('originalDataset/x_train/aum_train/aum_m11.csv')
aum_m9 = pd.read_csv('originalDataset/x_train/aum_train/aum_m12.csv')

# %%
### 这里解释一下为什么要用1，2，3而非原本的月份数：这里表示的是季度内第一个，第二个和第三个月。
df3 = pd.merge(
    changeColName(aum_m7, "aum_m1"), changeColName(aum_m8, "aum_m2"), 
    how='outer',on='cust_no'
)

df3 = pd.merge(
    df3, changeColName(aum_m9, "aum_m3"), 
    how='outer',on='cust_no'
)

# %%
behavior_m7 = pd.read_csv('originalDataset/x_train/behavior_train/behavior_m10.csv')
behavior_m8 = pd.read_csv('originalDataset/x_train/behavior_train/behavior_m11.csv')
behavior_m9 = pd.read_csv('originalDataset/x_train/behavior_train/behavior_m12.csv')

# %%
df3 = pd.merge(
    df3, changeColName(behavior_m7, "behavior_m1"), 
    how='outer',on='cust_no'
)

df3 = pd.merge(
    df3, changeColName(behavior_m8, "behavior_m2"), 
    how='outer',on='cust_no'
)

df3 = pd.merge(
    df3, changeColName(behavior_m9, "behavior_m3"), 
    how='outer',on='cust_no'
)

# %%
big_event_q3 = pd.read_csv('originalDataset/x_train/big_event_train/big_event_Q4.csv')
# big_event_q4 = pd.read_csv('originalDataset/x_train/big_event_train/big_event_Q4.csv')

# %%
df3 = pd.merge(
    df3, changeColName(big_event_q3, "big_event"), 
    how='outer',on='cust_no'
)

# %%
cunkuan_m7 = pd.read_csv('originalDataset/x_train/cunkuan_train/cunkuan_m10.csv')
cunkuan_m8 = pd.read_csv('originalDataset/x_train/cunkuan_train/cunkuan_m11.csv')
cunkuan_m9 = pd.read_csv('originalDataset/x_train/cunkuan_train/cunkuan_m12.csv')

# %%
df3 = pd.merge(
    df3, changeColName(cunkuan_m7, "cunkuan_m1"), 
    how='outer',on='cust_no'
)

df3 = pd.merge(
    df3, changeColName(cunkuan_m8, "cunkuan_m2"), 
    how='outer',on='cust_no'
)

df3 = pd.merge(
    df3, changeColName(cunkuan_m9, "cunkuan_m3"), 
    how='outer',on='cust_no'
)

# %%
cust_avli_q3 = pd.read_csv('originalDataset/x_train/cust_avli_Q4.csv')
# cust_avli_q4 = pd.read_csv('originalDataset/x_train/cust_avli_Q4.csv')

# %%
df3 = pd.merge(
    df3, changeColName(cust_avli_q3, "cust_avli"), 
    how='outer',on='cust_no'
)

# %%
cust_info_q3 = pd.read_csv('originalDataset/x_train/cust_info_q4.csv')
# cust_info_q4 = pd.read_csv('originalDataset/x_train/cust_info_q4.csv')

# %%
df3 = pd.merge(
    df3, changeColName(cust_info_q3, "cust_info"), 
    how='outer',on='cust_no'
)

# %%
y_q3 = pd.read_csv('originalDataset/y_train_3/y_Q4_3.csv')
# y_q4= pd.read_csv('originalDataset/y_train_3/y_Q4_3.csv')

# %%
df3 = pd.merge(
    df3, y_q3, 
    how='outer',on='cust_no'
)

# %%
df3.head()
# Out:
#       cust_no  aum_m1_X1  aum_m1_X2  aum_m1_X3  aum_m1_X4  aum_m1_X5  \
# 0  0xb2d67148        0.0        0.0       0.00        0.0        0.0
# 1  0xb2d06707        0.0        0.0       0.00        0.0        0.0
# 2  0xb2d7a54f        0.0        0.0       0.00        0.0        0.0
# 3  0xb2d3d976    27000.0        0.0   25037.87    50000.0        0.0
# 4  0xb2d1abaf        0.0        0.0       0.00        0.0        0.0
#
#    aum_m1_X6  aum_m1_X7  aum_m1_X8  aum_m2_X1  ...  cust_info_I12  \
# 0        0.0        0.0        0.0        0.0  ...             个人
# 1        0.0        0.0        0.0        0.0  ...             个人
# 2        0.0        0.0        0.0        0.0  ...             个人
# 3        0.0        0.0        0.0        0.0  ...             个人
# 4        0.0        0.0        0.0        0.0  ...             个人
#
#    cust_info_I13  cust_info_I14  cust_info_I15  cust_info_I16  cust_info_I17  \
# 0            NaN            NaN            0.0            0.0            1.0
# 1            NaN            NaN            0.0            0.0            1.0
# 2            NaN            NaN            0.0            0.0            0.0
# 3            NaN            NaN            0.0            1.0            1.0
# 4            NaN            NaN            0.0            0.0            1.0
#
#    cust_info_I18  cust_info_I19  cust_info_I20  label
# 0            1.0            1.0            0.0    NaN
# 1            1.0            0.0            0.0    NaN
# 2            0.0            0.0            0.0    NaN
# 3            1.0            1.0            0.0    1.0
# 4            1.0            1.0            0.0    NaN
#
# [5 rows x 87 columns]

# %%
df3.to_csv("preprocessedData/quarter4_merged.csv", index = False)

# %% [markdown]
# duplicate the above operations, to merge data for quarter 4 and 1.

# %% [markdown]
# ## Look deeper into the dataset

# %%
## load the dataset if necessary
# df3 = pd.read_csv('preprocessedData/quarter3_merged.csv')

# %%
df3_noNullLabel = df3[pd.notnull(df3['label'])]
df3_noNullLabel.head()
# Out:
#        cust_no  aum_m1_X1  aum_m1_X2  aum_m1_X3  aum_m1_X4  aum_m1_X5  \
# 3   0xb2d3d976    27000.0        0.0   25037.87    50000.0        0.0
# 20  0xb2d5f708        0.0        0.0      79.88        0.0        0.0
# 23  0xb2d6d4ea        0.0        0.0    5002.27        0.0        0.0
# 26  0xb2d91fbb   120000.0        0.0       5.28        0.0        0.0
# 30  0xb2d45b18    22000.0        0.0     745.37        0.0        0.0
#
#     aum_m1_X6  aum_m1_X7  aum_m1_X8  aum_m2_X1  ...  cust_info_I12  \
# 3        0.00        0.0        0.0        0.0  ...             个人
# 20  154086.89        0.0        0.0        0.0  ...             个人
# 23       0.00        0.0        0.0        0.0  ...             个人
# 26       0.00        0.0        0.0   120000.0  ...             个人
# 30       0.00        0.0        0.0    22000.0  ...             个人
#
#     cust_info_I13  cust_info_I14  cust_info_I15  cust_info_I16  cust_info_I17  \
# 3             NaN            NaN            0.0            1.0            1.0
# 20            NaN            NaN            0.0            1.0            1.0
# 23            NaN            NaN            0.0            0.0            1.0
# 26            NaN            NaN            0.0            1.0            1.0
# 30            NaN            NaN            0.0            0.0            1.0
#
#     cust_info_I18  cust_info_I19  cust_info_I20  label
# 3             1.0            1.0            0.0    1.0
# 20            1.0            1.0            0.0   -1.0
# 23            1.0            1.0            0.0    1.0
# 26            1.0            1.0            0.0    1.0
# 30            1.0            1.0            0.0    1.0
#
# [5 rows x 87 columns]

# %%
df3_noNullLabel.shape
# Out:
# (76170, 87)

# %%
df3_noNullLabel.to_csv("preprocessedData/quarter4_merged-validLabels.csv", index = False)

# %%
df3_noNullLabel.shape
# Out:
# (76170, 87)

# %%
# nan可视化
def seeWhichColumnsHaveMissingValues(data_train): 
    missing = data_train.isnull().sum()/len(data_train)
    missing = missing[missing > 0]
    missing.sort_values(inplace=True)
    missing.plot.bar()
seeWhichColumnsHaveMissingValues(df3_noNullLabel)

# %% [markdown]
# From the above plot, we find that there are several columns contains very big proportion of null value. We'd better give up such columns.

# %% [markdown]
# I suggest we delete the columns that only have 0-1 columns

# %% [markdown]
# ### object type data columns

# %%
numerical_fea = list(df3_noNullLabel.select_dtypes(exclude=['object']).columns)
object_fea = list(filter(lambda x: x not in numerical_fea,list(df3_noNullLabel.columns)))
label = 'label'
numerical_fea.remove(label)

# %%
print(numerical_fea)
# Out:
# ['aum_m1_X1', 'aum_m1_X2', 'aum_m1_X3', 'aum_m1_X4', 'aum_m1_X5', 'aum_m1_X6', 'aum_m1_X7', 'aum_m1_X8', 'aum_m2_X1', 'aum_m2_X2', 'aum_m2_X3', 'aum_m2_X4', 'aum_m2_X5', 'aum_m2_X6', 'aum_m2_X7', 'aum_m2_X8', 'aum_m3_X1', 'aum_m3_X2', 'aum_m3_X3', 'aum_m3_X4', 'aum_m3_X5', 'aum_m3_X6', 'aum_m3_X7', 'aum_m3_X8', 'behavior_m1_B1', 'behavior_m1_B2', 'behavior_m1_B3', 'behavior_m1_B4', 'behavior_m1_B5', 'behavior_m2_B1', 'behavior_m2_B2', 'behavior_m2_B3', 'behavior_m2_B4', 'behavior_m2_B5', 'behavior_m3_B1', 'behavior_m3_B2', 'behavior_m3_B3', 'behavior_m3_B4', 'behavior_m3_B5', 'behavior_m3_B7', 'big_event_E11', 'big_event_E15', 'big_event_E17', 'cunkuan_m1_C1', 'cunkuan_m1_C2', 'cunkuan_m2_C1', 'cunkuan_m2_C2', 'cunkuan_m3_C1', 'cunkuan_m3_C2', 'cust_info_I2', 'cust_info_I4', 'cust_info_I6', 'cust_info_I7', 'cust_info_I9', 'cust_info_I11', 'cust_info_I15', 'cust_info_I16', 'cust_info_I17', 'cust_info_I18', 'cust_info_I19', 'cust_info_I20']

# %%
## let's see what values do object features have: 
for fea in numerical_fea:
    if fea == "cust_no":
        continue
    print(f"==============={fea}=========================")
    print(df3_noNullLabel[fea].nunique())
#     print(df3_noNullLabel[fea].value_counts())
# Out:
# ===============aum_m1_X1=========================
# 1990
# ===============aum_m1_X2=========================
# 822
# ===============aum_m1_X3=========================
# 49748
# ===============aum_m1_X4=========================
# 727
# ===============aum_m1_X5=========================
# 3948
# ===============aum_m1_X6=========================
# 1283
# ===============aum_m1_X7=========================
# 5180
# ===============aum_m1_X8=========================
# 615
# ===============aum_m2_X1=========================
# 2021
# ===============aum_m2_X2=========================
# 836
# ===============aum_m2_X3=========================
# 49870
# ===============aum_m2_X4=========================
# 708
# ===============aum_m2_X5=========================
# 4137
# ===============aum_m2_X6=========================
# 1295
# ===============aum_m2_X7=========================
# 5256
# ===============aum_m2_X8=========================
# 642
# ===============aum_m3_X1=========================
# 2050
# ===============aum_m3_X2=========================
# 869
# ===============aum_m3_X3=========================
# 52362
# ===============aum_m3_X4=========================
# 754
# ===============aum_m3_X5=========================
# 4301
# ===============aum_m3_X6=========================
# 1340
# ===============aum_m3_X7=========================
# 5344
# ===============aum_m3_X8=========================
# 709
# ===============behavior_m1_B1=========================
# 154
# ===============behavior_m1_B2=========================
# 108
# ===============behavior_m1_B3=========================
# 16663
# ===============behavior_m1_B4=========================
# 116
# ===============behavior_m1_B5=========================
# 8887
# ===============behavior_m2_B1=========================
# 152
# ===============behavior_m2_B2=========================
# 107
# ===============behavior_m2_B3=========================
# 14034
# ===============behavior_m2_B4=========================
# 112
# ===============behavior_m2_B5=========================
# 8245
# ===============behavior_m3_B1=========================
# 172
# ===============behavior_m3_B2=========================
# 111
# ===============behavior_m3_B3=========================
# 16597
# ===============behavior_m3_B4=========================
# 120
# ===============behavior_m3_B5=========================
# 9165
# ===============behavior_m3_B7=========================
# 605
# ===============big_event_E11=========================
# 0
# ===============big_event_E15=========================
# 7310
# ===============big_event_E17=========================
# 7638
# ===============cunkuan_m1_C1=========================
# 57515
# ===============cunkuan_m1_C2=========================
# 92
# ===============cunkuan_m2_C1=========================
# 58418
# ===============cunkuan_m2_C2=========================
# 91
# ===============cunkuan_m3_C1=========================
# 62263
# ===============cunkuan_m3_C2=========================
# 90
# ===============cust_info_I2=========================
# 97
# ===============cust_info_I4=========================
# 2
# ===============cust_info_I6=========================
# 2
# ===============cust_info_I7=========================
# 1
# ===============cust_info_I9=========================
# 0
# ===============cust_info_I11=========================
# 730
# ===============cust_info_I15=========================
# 2
# ===============cust_info_I16=========================
# 2
# ===============cust_info_I17=========================
# 2
# ===============cust_info_I18=========================
# 2
# ===============cust_info_I19=========================
# 2
# ===============cust_info_I20=========================
# 2

# %%
# #每个数字特征得分布可视化
# f = pd.melt(df3_noNullLabel, value_vars=numerical_fea)
# g = sns.FacetGrid(f, col="variable",  col_wrap=4, sharex=False, sharey=False)
# g = g.map(sns.distplot, "value")

# %%
def plotEachCol(data_train, features):
    for fea in features:
        plt.figure(figsize=(10, 4))
        sns.barplot(data_train[fea].value_counts(dropna=False),
                    data_train[fea].value_counts(dropna=False).keys())
        plt.show()
plotEachCol(df3_noNullLabel, numerical_fea
           )

# %%
## 过滤类别较少的和较多的列
def get_numerical_serial_fea(data,feas):
    numerical_serial_fea = []
    numerical_noserial_fea = []
    for fea in feas:
        temp = data[fea].nunique()
        if temp <= 10:
            numerical_noserial_fea.append(fea)
            continue
        numerical_serial_fea.append(fea)
    return numerical_serial_fea,numerical_noserial_fea
    
numerical_serial_fea,numerical_noserial_fea = get_numerical_serial_fea(df3_noNullLabel,numerical_fea)

# %%
numerical_serial_fea
# Out:
# ['aum_m1_X1',
#  'aum_m1_X2',
#  'aum_m1_X3',
#  'aum_m1_X4',
#  'aum_m1_X5',
#  'aum_m1_X6',
#  'aum_m1_X7',
#  'aum_m1_X8',
#  'aum_m2_X1',
#  'aum_m2_X2',
#  'aum_m2_X3',
#  'aum_m2_X4',
#  'aum_m2_X5',
#  'aum_m2_X6',
#  'aum_m2_X7',
#  'aum_m2_X8',
#  'aum_m3_X1',
#  'aum_m3_X2',
#  'aum_m3_X3',
#  'aum_m3_X4',
#  'aum_m3_X5',
#  'aum_m3_X6',
#  'aum_m3_X7',
#  'aum_m3_X8',
#  'behavior_m1_B1',
#  'behavior_m1_B2',
#  'behavior_m1_B3',
#  'behavior_m1_B4',
#  'behavior_m1_B5',
#  'behavior_m2_B1',
#  'behavior_m2_B2',
#  'behavior_m2_B3',
#  'behavior_m2_B4',
#  'behavior_m2_B5',
#  'behavior_m3_B1',
#  'behavior_m3_B2',
#  'behavior_m3_B3',
#  'behavior_m3_B4',
#  'behavior_m3_B5',
#  'behavior_m3_B7',
#  'big_event_E15',
#  'big_event_E17',
#  'cunkuan_m1_C1',
#  'cunkuan_m1_C2',
#  'cunkuan_m2_C1',
#  'cunkuan_m2_C2',
#  'cunkuan_m3_C1',
#  'cunkuan_m3_C2',
#  'cust_info_I2',
#  'cust_info_I11']

# %%
numerical_noserial_fea
# Out:
# ['big_event_E11',
#  'cust_info_I4',
#  'cust_info_I6',
#  'cust_info_I7',
#  'cust_info_I9',
#  'cust_info_I15',
#  'cust_info_I16',
#  'cust_info_I17',
#  'cust_info_I18',
#  'cust_info_I19',
#  'cust_info_I20']

# %% [markdown]
# ### object type featues

# %%
print(object_fea)
# Out:
# ['cust_no', 'behavior_m3_B6', 'big_event_E1', 'big_event_E2', 'big_event_E3', 'big_event_E4', 'big_event_E5', 'big_event_E6', 'big_event_E7', 'big_event_E8', 'big_event_E9', 'big_event_E10', 'big_event_E12', 'big_event_E13', 'big_event_E14', 'big_event_E16', 'big_event_E18', 'cust_info_I1', 'cust_info_I3', 'cust_info_I5', 'cust_info_I8', 'cust_info_I10', 'cust_info_I12', 'cust_info_I13', 'cust_info_I14']

# %%
## let's see what values do object features have: 
for fea in object_fea:
    if fea == "cust_no":
        continue
    print(f"==============={fea}=========================")
    print(df3_noNullLabel[fea].nunique())
    print(df3_noNullLabel[fea].value_counts())
# Out:
# ===============behavior_m3_B6=========================
# 22077
# 2019-09-21 23:50:00    537
# 2019-09-21 23:51:00    504
# 2019-09-21 23:52:00    343
# 2019-09-21 23:54:00    307
# 2019-09-30 18:34:00    304
# 2019-09-30 18:35:00    298
# 2019-09-21 23:53:00    279
# 2019-09-30 18:33:00    236
# 2019-09-30 05:01:00    215
# 2019-09-30 04:51:00    194
# 2019-09-30 04:49:00    193
# 2019-09-30 18:36:00    180
# 2019-09-30 04:56:00    179
# 2019-09-30 04:59:00    179
# 2019-09-27 08:55:00    156
# 2019-09-30 04:47:00    155
# 2019-09-30 04:53:00    154
# 2019-09-30 05:03:00    152
# 2019-09-27 08:50:00    151
# 2019-09-30 04:54:00    150
# 2019-09-27 08:45:00    145
# 2019-09-27 08:48:00    143
# 2019-09-24 07:13:00    138
# 2019-09-23 01:46:00    126
# 2019-09-20 04:38:00    126
# 2019-09-21 23:49:00    126
# 2019-09-24 07:10:00    123
# 2019-09-27 08:52:00    122
# 2019-09-20 04:35:00    119
# 2019-09-30 02:08:00    119
#                       ...
# 2019-08-13 09:55:00      1
# 2019-09-28 09:23:00      1
# 2019-08-29 17:30:00      1
# 2019-04-03 17:18:00      1
# 2019-07-06 16:49:00      1
# 2019-07-29 09:58:00      1
# 2019-09-19 07:57:00      1
# 2019-07-04 16:34:00      1
# 2019-08-22 11:24:00      1
# 2019-08-31 18:07:00      1
# 2019-05-27 18:08:00      1
# 2019-09-09 15:53:00      1
# 2019-09-04 21:08:00      1
# 2019-09-21 06:29:00      1
# ===============cust_info_I3=========================
# 4
# 普通客户    33985
# 黄金      25912
# 白金       8415
# 钻石        814
# Name: cust_info_I3, dtype: int64
# ===============cust_info_I5=========================
# 11
# 不便分类的其他从业人员             18524
# 商业工作人员                  13338
# 服务性工作人员                 11454
# 办事人员和有关人员                9078
# 专业技术人员                   3457
# 未知                       2489
# 国家机关、党群组织、企业、事业单位负责人     1782
# 生产、运输设备操作人员及有关人员         1435
# 农、林、牧、渔、水利业生产人员           605
# 军人                         34
# 退休                          5
# Name: cust_info_I5, dtype: int64
# ===============cust_info_I8=========================
# 12
# 天秤座    7138
# 天蝎座    6697
# 处女座    6124
# 狮子座    5900
# 摩羯座    5835
# 射手座    5817
# 水瓶座    5660
# 双鱼座    5528
# 巨蟹座    5394
# 双子座    5100
# 白羊座    4991
# 金牛座    4942
# Name: cust_info_I8, dtype: int64
# ===============cust_info_I10=========================
# 10
# 大学本科        2942
# 专科教育        1676
# 普通高级中学教育    1143
# 初级中学教育       742
# 中等职业教育       470
# 研究生教育        361
# 未知           301
# 小学教育         154
# 技工学校毕业        25
# 文盲或半文盲         1
# Name: cust_info_I10, dtype: int64
# ===============cust_info_I12=========================
# 1
# 个人    69126
# Name: cust_info_I12, dtype: int64
# ===============cust_info_I13=========================
# 6
# 已婚          360
# 未婚          317
# 离婚           18
# 其他            9
# 未说明的婚姻状况      7
# 丧偶            1
# Name: cust_info_I13, dtype: int64
# ===============cust_info_I14=========================
# 6
# 高级领导(行政级别局级及局级以上领导或大公司高级管理人员)     3927
# 其他                                1167
# 中级领导(行政级别局级以下处级以上领导或大公司中级管理人员)     839
# 一般员工                               788
# 未知                                 281
# 初级领导(行政级别处级以下领导或大公司初级管理人员)         236
# Name: cust_info_I14, dtype: int64

# %%
df3_noNullLabel["label"].nunique()
# Out:
# 3

# %% [markdown]
# # (Recycle bin)

# %% [markdown]
# ## Load preprocessed dataset

# %%
data_train = pd.read_csv('preprocessedData/lagrangeInterpolated_train-1.csv')
data_test_a = pd.read_csv('preprocessedData/lagrangeInterpolated_test-1.csv')

# %%
data_train_cp = data_train.copy()
data_test_a_cp = data_test_a.copy()

# %%
# data_train.isnull().sum()

# %% [markdown]
# ## See how many columns have null values

# %%
# nan可视化
def seeWhichColumnsHaveMissingValues(data_train): 
    missing = data_train.isnull().sum()/len(data_train)
    missing = missing[missing > 0]
    missing.sort_values(inplace=True)
    missing.plot.bar()
seeWhichColumnsHaveMissingValues(data_train)
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-10-7331eaa2f554> in <module>()
#       5     missing.sort_values(inplace=True)
#       6     missing.plot.bar()
# ----> 7 seeWhichColumnsHaveMissingValues(data_train)
#
# <ipython-input-10-7331eaa2f554> in seeWhichColumnsHaveMissingValues(data_train)
#       4     missing = missing[missing > 0]
#       5     missing.sort_values(inplace=True)
# ----> 6     missing.plot.bar()
#       7 seeWhichColumnsHaveMissingValues(data_train)
#
# /usr/local/lib/python3.6/dist-packages/pandas/plotting/_core.py in bar(self, x, y, **kwargs)
#    1105         other axis represents a measured value.
#    1106         """
# -> 1107         return self(kind="bar", x=x, y=y, **kwargs)
#    1108
#    1109     @Appender(
#
# /usr/local/lib/python3.6/dist-packages/pandas/plotting/_core.py in __call__(self, *args, **kwargs)
#     947                     data.columns = label_name
#     948
# --> 949         return plot_backend.plot(data, kind=kind, **kwargs)
#     950
#     951     __call__.__doc__ = __doc__
#
# /usr/local/lib/python3.6/dist-packages/pandas/plotting/_matplotlib/__init__.py in plot(data, kind, **kwargs)
#      59             kwargs["ax"] = getattr(ax, "left_ax", ax)
#      60     plot_obj = PLOT_CLASSES[kind](data, **kwargs)
# ---> 61     plot_obj.generate()
#      62     plot_obj.draw()
#      63     return plot_obj.result
#
# /usr/local/lib/python3.6/dist-packages/pandas/plotting/_matplotlib/core.py in generate(self)
#     276         for ax in self.axes:
#     277             self._post_plot_logic_common(ax, self.data)
# --> 278             self._post_plot_logic(ax, self.data)
#     279
#     280     def _args_adjust(self):
#
# /usr/local/lib/python3.6/dist-packages/pandas/plotting/_matplotlib/core.py in _post_plot_logic(self, ax, data)
#    1459         name = self._get_index_name()
#    1460
# -> 1461         s_edge = self.ax_pos[0] - 0.25 + self.lim_offset
#    1462         e_edge = self.ax_pos[-1] + 0.25 + self.bar_width + self.lim_offset
#    1463
#
# IndexError: index 0 is out of bounds for axis 0 with size 0

# %%
seeWhichColumnsHaveMissingValues(data_test_a)

# %% [markdown]
# ## Numerical features and category features

# %%
numerical_fea = list(data_train.select_dtypes(exclude=['object']).columns)
category_fea = list(filter(lambda x: x not in numerical_fea,list(data_train.columns)))
label = 'isDefault'
numerical_fea.remove(label)

# %%
#过滤数值型类别特征
def get_numerical_serial_fea(data,feas):
    numerical_serial_fea = []
    numerical_noserial_fea = []
    for fea in feas:
        temp = data[fea].nunique()
        if temp <= 10:
            numerical_noserial_fea.append(fea)
            continue
        numerical_serial_fea.append(fea)
    return numerical_serial_fea,numerical_noserial_fea
numerical_serial_fea,numerical_noserial_fea = get_numerical_serial_fea(data_train,numerical_fea)

# %%
len(data_train.columns)
# Out:
# 47

# %%
len(numerical_serial_fea)
# Out:
# 33

# %%
len(numerical_noserial_fea)
# Out:
# 8

# %%
len(category_fea)
# Out:
# 5

# %%
label
# Out:
# 'isDefault'

# %% [markdown]
# All in all, not columns are having too much null value.

# %% [markdown]
# ### See the `numerical_nonserial_fea` and get some value counts result

# %%
for fea in numerical_noserial_fea:
    print("--------{}----------".format(fea))
    print(data_train[fea].value_counts())
# Out:
# --------term----------
# 3    606902
# 5    193098
# Name: term, dtype: int64
# --------homeOwnership----------
# 0    395732
# 1    317660
# 2     86309
# 3       185
# 5        81
# 4        33
# Name: homeOwnership, dtype: int64
# --------verificationStatus----------
# 1    309810
# 2    248968
# 0    241222
# Name: verificationStatus, dtype: int64
# --------initialListStatus----------
# 0    466438
# 1    333562
# Name: initialListStatus, dtype: int64
# --------applicationType----------
# 0    784586
# 1     15414
# Name: applicationType, dtype: int64
# --------policyCode----------
# 1.0    800000
# Name: policyCode, dtype: int64
# --------n11----------
# 0.0    729682
# 1.0       540
# 2.0        24
# 4.0         1
# 3.0         1
# Name: n11, dtype: int64
# --------n12----------
# 0.0    757315
# 1.0      2281
# 2.0       115
# 3.0        16
# 4.0         3
# Name: n12, dtype: int64

# %% [markdown]
# **Mind this**:
# * No need to keep the `policyCode`.
# * ~Let's try to delete the `n11` and `n12`? Seems that it is not very useful. The data is very biased.~
# * We can make them one-hot. Or not.

# %% [markdown]
# ### See `category_fea`

# %%
category_fea
# Out:
# ['grade', 'subGrade', 'employmentLength', 'issueDate', 'earliesCreditLine']

# %%
for fea in category_fea:
    print("--------{}----------".format(fea))
    print(data_train[fea].value_counts())
# Out:
# --------grade----------
# B    233690
# C    227118
# A    139661
# D    119453
# E     55661
# F     19053
# G      5364
# Name: grade, dtype: int64
# --------subGrade----------
# C1    50763
# B4    49516
# B5    48965
# B3    48600
# C2    47068
# C3    44751
# C4    44272
# B2    44227
# B1    42382
# C5    40264
# A5    38045
# A4    30928
# D1    30538
# D2    26528
# A1    25909
# D3    23410
# A3    22655
# A2    22124
# D4    21139
# D5    17838
# E1    14064
# E2    12746
# E3    10925
# E4     9273
# E5     8653
# F1     5925
# F2     4340
# F3     3577
# F4     2859
# F5     2352
# G1     1759
# G2     1231
# G3      978
# G4      751
# G5      645
# Name: subGrade, dtype: int64
# --------employmentLength----------
# 10+ years    262753
# 2 years       72358
# < 1 year      64237
# 3 years       64152
# 1 year        52489
# 5 years       50102
# 4 years       47985
# 6 years       37254
# 8 years       36192
# 7 years       35407
# 9 years       30272
# Name: employmentLength, dtype: int64
# --------issueDate----------
# 2016-03-01    29066
# 2015-10-01    25525
# 2015-07-01    24496
# 2015-12-01    23245
# 2014-10-01    21461
#               ...
# 2007-08-01       23
# 2007-07-01       21
# 2008-09-01       19
# 2007-09-01        7
# 2007-06-01        1
# Name: issueDate, Length: 139, dtype: int64
# --------earliesCreditLine----------
# Aug-2001    5567
# Sep-2003    5403
# Aug-2002    5403
# Oct-2001    5258
# Aug-2000    5246
#             ...
# Mar-1957       1
# Mar-1958       1
# Jan-1944       1
# Jan-1946       1
# Oct-1957       1
# Name: earliesCreditLine, Length: 720, dtype: int64

# %% [markdown]
# We should encode these into numbers.

# %% [markdown]
# ### See the distribution of `numerical_serial_fea`

# %% [markdown]
# We can learn that all of the numerical serial features are above zero.

# %%
#每个数字特征得分布可视化
f = pd.melt(data_train, value_vars=numerical_serial_fea)
g = sns.FacetGrid(f, col="variable",  col_wrap=4, sharex=False, sharey=False)
g = g.map(sns.distplot, "value")

# %%
#每个数字特征得分布可视化
f1 = pd.melt(data_test_a, value_vars=numerical_serial_fea)
g1 = sns.FacetGrid(f1, col="variable",  col_wrap=4, sharex=False, sharey=False)
g1 = g1.map(sns.distplot, "value")

# %% [markdown]
# If we log the `numerical_seriel_fea`:

# %%
# data_train_log = np.log(data_train)
# data_test_a_log = np.log(data_test_a)

data_train_cp = data_train.copy()
data_test_a_cp = data_test_a.copy()

for data in [data_train_cp, data_test_a_cp]:
    for fea in numerical_serial_fea:
        if fea in ["id"]:
            continue
        data[fea] = np.log1p(np.log1p(data[fea]))

# %%
# 二阶log1p
f1 = pd.melt(data_test_a_cp, value_vars=numerical_serial_fea)
g1 = sns.FacetGrid(f1, col="variable",  col_wrap=4, sharex=False, sharey=False)
g1 = g1.map(sns.distplot, "value")

# %%
#一阶log1p
f1 = pd.melt(data_test_a_cp, value_vars=numerical_serial_fea)
g1 = sns.FacetGrid(f1, col="variable",  col_wrap=4, sharex=False, sharey=False)
g1 = g1.map(sns.distplot, "value")

# %%
# data_train_cp["title"].value_counts()
plt.figure(figsize=(20, 8))
sns.barplot(data_train["title"].value_counts(dropna=False),
            data_train["title"].value_counts(dropna=False).keys())
plt.show()

# %%
# for fea in numerical_serial_fea: 
#     print("------{}-------".format(fea))
#     print(data_train[fea].value_counts().sort_index())

# data_train_cp.replace([np.inf, -np.inf], 0, inplace=True)
# data_test_a_cp.replace([np.inf, -np.inf], 0, inplace=True)
